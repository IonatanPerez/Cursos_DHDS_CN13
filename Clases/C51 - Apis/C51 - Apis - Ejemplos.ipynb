# %%
import requests
from tqdm import tqdm

# %%
url = "http://www.google.com/Ionatan/"
r = requests.get(url)

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}\n  </style>\n  <a href=//www.google.com/><span id=logo aria-label=Google></span></a>\n  <p><b>404.</b> <ins>That\xe2\x80\x99s an error.</ins>\n  <p>The requested URL <code>/Ionatan/</code> was not found on this server.  <ins>That\xe2\x80\x99s all we know.</ins>\n'

# %%
url = "https://api.mercadolibre.com/sites/MLA/categories"
r = requests.get(url)
r.json()

# %%
url = "https://api.mercadolibre.com/sites/MLA/search?q=olla&offset=101"
r = requests.get(url)
r.json()['results']
# Out:
# [{'id': 'MLA929609347',
#   'title': 'Cacerola Tefal Pratika 24 Cm Olla Tapa Vidrio Antiadherente',
#   'condition': 'new',
#   'thumbnail_id': '955634-MLA47654284358_092021',
#   'catalog_product_id': 'MLA8933515',
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-929609347-cacerola-tefal-pratika-24-cm-olla-tapa-vidrio-antiadherente-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_955634-MLA47654284358_092021-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 1,
#   'price': 12699,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 5,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2041-07-10T04:00:00.000Z',
#   'seller': {'id': 157925509,
#    'nickname': 'COOKING STORE',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2014-04-28T14:23:15.000-04:00',
#    'tags': ['normal',
#     'credits_priority_4',
#     'eshop',
#     'medium_seller',
#     'credits_profile',
#     'mshops',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/COOKING+STORE',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 694,
#      'completed': 13954,
#      'period': 'historic',
#      'ratings': {'negative': 0.03, 'neutral': 0.01, 'positive': 0.96},
#      'total': 14648},
#     'metrics': {'sales': {'period': '60 days', 'completed': 2117},
#      'claims': {'period': '60 days', 'rate': 0.0063, 'value': 14},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.055,
#       'value': 117},
#      'cancellations': {'period': '60 days', 'rate': 0.0031, 'value': 7}}},
#    'eshop': {'eshop_id': 251968,
#     'seller': 157925509,
#     'nick_name': 'COOKING STORE',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/157925509va0332f.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#    'city': {'id': 'TUxBQlZJTDc4MDda', 'name': 'Villa del Parque'}},
#   'address': {'state_id': 'AR-C',
#    'state_name': 'Capital Federal',
#    'city_id': 'TUxBQlZJTDc4MDda',
#    'city_name': 'Villa del Parque'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '3631',
#     'value_name': 'Tefal',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '3631',
#       'name': 'Tefal',
#       'struct': None,
#       'source': 1138849081739375}],
#     'source': 1138849081739375,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': '2373774',
#     'value_name': 'Pratika',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2373774',
#       'name': 'Pratika',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'PRÁTIKA',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'PRÁTIKA',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359391',
#     'value_name': 'Unidad',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '1',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '-1',
#     'value_name': None,
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '-1',
#       'name': None,
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'number_unit'}],
#   'variations_data': {'91192319346': {'thumbnail': 'http://http2.mlstatic.com/D_955634-MLA47654284358_092021-O.jpg',
#     'ratio': '1.75',
#     'name': 'Negro',
#     'pictures_qty': 2}},
#   'installments': {'quantity': 6,
#    'amount': 3139.83,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA852054216',
#   'title': 'Olla Pochoclera  Familiar Jovifel Con Cuchara De Regalo ',
#   'condition': 'new',
#   'thumbnail_id': '776761-MLA41931585076_052020',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-852054216-olla-pochoclera-familiar-jovifel-con-cuchara-de-regalo-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA418359',
#   'domain_id': 'MLA-STOVETOP_POPCORN_POPPERS',
#   'thumbnail': 'http://http2.mlstatic.com/D_776761-MLA41931585076_052020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 2,
#   'price': 4759,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 500,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['brand_verified',
#    'good_quality_picture',
#    'good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': False,
#    'tags': ['self_service_in'],
#    'promise': None},
#   'stop_time': '2042-03-11T17:59:59.000Z',
#   'seller': {'id': 116751523,
#    'nickname': 'DETODOCLAYPOLE',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2012-07-13T11:56:03.000-04:00',
#    'tags': ['normal',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/DETODOCLAYPOLE',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 1623,
#      'completed': 37923,
#      'period': 'historic',
#      'ratings': {'negative': 0.02, 'neutral': 0.01, 'positive': 0.97},
#      'total': 39546},
#     'metrics': {'sales': {'period': '60 days', 'completed': 5591},
#      'claims': {'period': '60 days', 'rate': 0.0047, 'value': 28},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0049,
#       'value': 28},
#      'cancellations': {'period': '60 days', 'rate': 0.0064, 'value': 38}}},
#    'eshop': {'eshop_id': 257865,
#     'seller': 116751523,
#     'nick_name': 'DETODOCLAYPOLE',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/logo-116751523-1675395426258.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': None, 'name': 'Claypole'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': None,
#    'city_name': 'Claypole'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '922344',
#     'value_name': 'Jovifel',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '922344',
#       'name': 'Jovifel',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Aluminio tamaño familiar',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Aluminio tamaño familiar',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'}],
#   'variations_data': {'54812961542': {'thumbnail': 'http://http2.mlstatic.com/D_776761-MLA41931585076_052020-O.jpg',
#     'ratio': '1.13',
#     'name': 'Gris',
#     'pictures_qty': 9}},
#   'installments': {'quantity': 6,
#    'amount': 1176.66,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA1100832118',
#   'title': 'Bateria De Cocina Set Ollas Allegra 4 Pzs Tramontina Acero',
#   'condition': 'new',
#   'thumbnail_id': '908941-MLA47322367522_092021',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1100832118-bateria-de-cocina-set-ollas-allegra-4-pzs-tramontina-acero-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA30098',
#   'domain_id': 'MLA-KITCHEN_COOKWARE_SETS',
#   'thumbnail': 'http://http2.mlstatic.com/D_908941-MLA47322367522_092021-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 3,
#   'price': 46119,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 5,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    'good_quality_picture',
#    'immediate_payment',
#    'cart_eligible'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'xd_drop_off',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2041-08-27T04:00:00.000Z',
#   'seller': {'id': 575126283,
#    'nickname': 'TORINOBAZAR',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2020-05-27T15:27:01.000-04:00',
#    'tags': ['normal',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/TORINOBAZAR',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 392,
#      'completed': 8438,
#      'period': 'historic',
#      'ratings': {'negative': 0.01, 'neutral': 0.02, 'positive': 0.97},
#      'total': 8830},
#     'metrics': {'sales': {'period': '60 days', 'completed': 1778},
#      'claims': {'period': '60 days', 'rate': 0.0043, 'value': 8},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0125,
#       'value': 22},
#      'cancellations': {'period': '60 days', 'rate': 0.0026, 'value': 5}}},
#    'eshop': {'eshop_id': 480975,
#     'seller': 575126283,
#     'nick_name': 'TORINOBAZAR',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/575126283v657c9c.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': None, 'name': 'Munro'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': None,
#    'city_name': 'Munro'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '433',
#     'value_name': 'Tramontina',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '433',
#       'name': 'Tramontina',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': None,
#     'value_name': 'Allegra',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Allegra',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': '65650/324',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '65650/324',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'string'}],
#   'variations_data': {'173566020143': {'thumbnail': 'http://http2.mlstatic.com/D_908941-MLA47322367522_092021-O.jpg',
#     'ratio': '1.77',
#     'name': 'Plateado',
#     'pictures_qty': 7}},
#   'installments': {'quantity': 6,
#    'amount': 11402.92,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA901025302',
#   'title': 'Juego De Ollas Set De 4 Piezas Tramontina Allegra 65650/324',
#   'condition': 'new',
#   'thumbnail_id': '963503-MLA44331302075_122020',
#   'catalog_product_id': 'MLA20025885',
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-901025302-juego-de-ollas-set-de-4-piezas-tramontina-allegra-65650324-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_963503-MLA44331302075_122020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 4,
#   'price': 50099,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 50,
#   'available_quantity': 1,
#   'official_store_id': 2977,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'brand_verified',
#    'catalog_listing_eligible',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2040-12-09T04:00:00.000Z',
#   'seller': {'id': 9877009,
#    'nickname': 'TIOMUSA',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2002-06-12T00:00:00.000-04:00',
#    'tags': ['brand',
#     'large_seller',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'credits_priority_4',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/TIOMUSA',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 6295,
#      'completed': 109269,
#      'period': 'historic',
#      'ratings': {'negative': 0.02, 'neutral': 0.03, 'positive': 0.95},
#      'total': 115564},
#     'metrics': {'sales': {'period': '60 days', 'completed': 17296},
#      'claims': {'period': '60 days', 'rate': 0.0076, 'value': 141},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0085,
#       'value': 120},
#      'cancellations': {'period': '60 days', 'rate': 0.0034, 'value': 63}}},
#    'eshop': {'eshop_id': 4138,
#     'seller': 9877009,
#     'nick_name': 'TIOMUSA',
#     'eshop_status_id': 2,
#     'site_id': 'MLA',
#     'eshop_experience': 1993,
#     'eshop_rubro': {'id': 'MLA5726',
#      'name': 'Electrodomésticos y Aires Ac.',
#      'category_id': 'MLA5726'},
#     'eshop_locations': [{'city': {'id': 'TUxBQkNBQjM4MDda'},
#       'country': {'id': 'AR'},
#       'neighborhood': {'id': None},
#       'state': {'id': 'AR-C'}},
#      {'state': {'id': 'AR-C'},
#       'city': {'id': 'TUxBQlBBVDI0ODFa'},
#       'country': {'id': 'AR'},
#       'neighborhood': {'id': None}},
#      {'state': {'id': 'AR-C'},
#       'city': {'id': 'TUxBQlZJTDcwOTla'},
#       'country': {'id': 'AR'},
#       'neighborhood': {'id': None}},
#      {'city': {'id': 'TUxBQlZJTDQyMjBa'},
#       'country': {'id': 'AR'},
#       'neighborhood': {'id': None},
#       'state': {'id': 'AR-C'}}],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/9877009vcbb1cf.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#    'city': {'id': 'TUxBQkNBQjM4MDda', 'name': 'Caballito'}},
#   'address': {'state_id': 'AR-C',
#    'state_name': 'Capital Federal',
#    'city_id': 'TUxBQkNBQjM4MDda',
#    'city_name': 'Caballito'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '433',
#     'value_name': 'Tramontina',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '433',
#       'name': 'Tramontina',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': '2124234',
#     'value_name': 'Allegra',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2124234',
#       'name': 'Allegra',
#       'struct': None,
#       'source': 1000427007642219}],
#     'source': 1000427007642219,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Allegra 65650/324',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Allegra 65650/324',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359392',
#     'value_name': 'Pack',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359392',
#       'name': 'Pack',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '4',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '4',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '-1',
#     'value_name': None,
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '-1',
#       'name': None,
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'number_unit'}],
#   'variations_data': {'70654086992': {'thumbnail': 'http://http2.mlstatic.com/D_963503-MLA44331302075_122020-O.jpg',
#     'ratio': '1.73',
#     'name': 'Gris',
#     'pictures_qty': 6}},
#   'installments': {'quantity': 6,
#    'amount': 12386.98,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA1302524260',
#   'title': 'Cacerola Hudson Antiadherente Ceramico 24 Cm',
#   'condition': 'new',
#   'thumbnail_id': '883315-MLA41808510636_052020',
#   'catalog_product_id': 'MLA19944340',
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://www.mercadolibre.com.ar/cacerola-hudson-antiadherente-ceramico-24-cm/p/MLA19944340',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_883315-MLA41808510636_052020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 5,
#   'price': 8549,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 1,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['brand_verified',
#    'good_quality_picture',
#    'good_quality_thumbnail',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['fs_threshold_mla_change_feb2021',
#     'self_service_in',
#     'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2043-01-01T04:00:00.000Z',
#   'seller': {'id': 116751523,
#    'nickname': 'DETODOCLAYPOLE',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2012-07-13T11:56:03.000-04:00',
#    'tags': ['normal',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/DETODOCLAYPOLE',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 1623,
#      'completed': 37923,
#      'period': 'historic',
#      'ratings': {'negative': 0.02, 'neutral': 0.01, 'positive': 0.97},
#      'total': 39546},
#     'metrics': {'sales': {'period': '60 days', 'completed': 5591},
#      'claims': {'period': '60 days', 'rate': 0.0047, 'value': 28},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0049,
#       'value': 28},
#      'cancellations': {'period': '60 days', 'rate': 0.0064, 'value': 38}}},
#    'eshop': {'eshop_id': 257865,
#     'seller': 116751523,
#     'nick_name': 'DETODOCLAYPOLE',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/logo-116751523-1675395426258.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': None, 'name': 'Claypole'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': None,
#    'city_name': 'Claypole'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '2333684',
#     'value_name': 'Hudson',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2333684',
#       'name': 'Hudson',
#       'struct': None,
#       'source': 1}],
#     'source': 1,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': '13811917',
#     'value_name': 'ACD07C',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '13811917',
#       'name': 'ACD07C',
#       'struct': None,
#       'source': 1}],
#     'source': 1,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359391',
#     'value_name': 'Unidad',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 1}],
#     'source': 1,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': '2726554',
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2726554', 'name': '1', 'struct': None, 'source': 1}],
#     'source': 1,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '1130924',
#     'value_name': '1.3 kg',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': {'number': 1.3, 'unit': 'kg'},
#     'values': [{'id': '1130924',
#       'name': '1.3 kg',
#       'struct': {'unit': 'kg', 'number': 1.3},
#       'source': 1}],
#     'source': 1,
#     'value_type': 'number_unit'}],
#   'installments': {'quantity': 6,
#    'amount': 2113.74,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'catalog_listing': True,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA886153965',
#   'title': 'Cacerola Antiadherente Hudson  26 Cm Aluminio',
#   'condition': 'new',
#   'thumbnail_id': '771831-MLA43953771320_102020',
#   'catalog_product_id': 'MLA19944327',
#   'listing_type_id': 'gold_pro',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-886153965-cacerola-antiadherente-hudson-26-cm-aluminio-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_771831-MLA43953771320_102020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 6,
#   'price': 10480,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 250,
#   'available_quantity': 1,
#   'official_store_id': 2276,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    'mshops_ahora-6',
#    'brand_verified',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2042-04-28T12:45:21.000Z',
#   'seller': {'id': 541979651,
#    'nickname': 'HUDSON COCINA',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2020-04-03T16:15:32.000-04:00',
#    'tags': ['brand',
#     'large_seller',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/HUDSON+COCINA',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 1207,
#      'completed': 25653,
#      'period': 'historic',
#      'ratings': {'negative': 0.03, 'neutral': 0.02, 'positive': 0.95},
#      'total': 26860},
#     'metrics': {'sales': {'period': '60 days', 'completed': 4637},
#      'claims': {'period': '60 days', 'rate': 0.0043, 'value': 21},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0052,
#       'value': 25},
#      'cancellations': {'period': '60 days', 'rate': 0, 'value': 1}}}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': None, 'name': 'Martínez'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': None,
#    'city_name': 'Martínez'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '2333684',
#     'value_name': 'Hudson',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2333684',
#       'name': 'Hudson',
#       'struct': None,
#       'source': 377188858949192}],
#     'source': 377188858949192,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 1}],
#     'source': 1,
#     'value_type': 'list'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': '13811931',
#     'value_name': 'TH36SF',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '13811931',
#       'name': 'TH36SF',
#       'struct': None,
#       'source': 377188858949192}],
#     'source': 377188858949192,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359391',
#     'value_name': 'Unidad',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 377188858949192}],
#     'source': 377188858949192,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '1',
#       'struct': None,
#       'source': 3942444344910321}],
#     'source': 3942444344910321,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '6819842',
#     'value_name': '1.35 kg',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': {'number': 1.35, 'unit': 'kg'},
#     'values': [{'id': '6819842',
#       'name': '1.35 kg',
#       'struct': {'number': 1.35, 'unit': 'kg'},
#       'source': 3942444344910321}],
#     'source': 3942444344910321,
#     'value_type': 'number_unit'}],
#   'variations_data': {'67140466032': {'thumbnail': 'http://http2.mlstatic.com/D_771831-MLA43953771320_102020-O.jpg',
#     'ratio': '1.91',
#     'name': 'Negro',
#     'pictures_qty': 8}},
#   'installments': {'quantity': 6,
#    'amount': 1746.67,
#    'rate': 0,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'differential_pricing': {'id': 33678187},
#   'inventory_id': None},
#  {'id': 'MLA1118109454',
#   'title': 'Set 7 Piezas Cocina Bateria Ollas Cacerola Sarten.',
#   'condition': 'new',
#   'thumbnail_id': '683347-MLA49275833629_032022',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1118109454-set-7-piezas-cocina-bateria-ollas-cacerola-sarten-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA30098',
#   'domain_id': 'MLA-KITCHEN_COOKWARE_SETS',
#   'thumbnail': 'http://http2.mlstatic.com/D_683347-MLA49275833629_032022-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 7,
#   'price': 9750,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 150,
#   'available_quantity': 50,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2041-12-29T04:00:00.000Z',
#   'seller': {'id': 161901507,
#    'nickname': 'IKO SHOP',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2014-07-03T15:38:42.000-04:00',
#    'tags': ['normal', 'credits_profile', 'mshops', 'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/IKO+SHOP',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 8671,
#      'completed': 141250,
#      'period': 'historic',
#      'ratings': {'negative': 0.03, 'neutral': 0.03, 'positive': 0.94},
#      'total': 149921},
#     'metrics': {'sales': {'period': '60 days', 'completed': 32306},
#      'claims': {'period': '60 days', 'rate': 0.0059, 'value': 205},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0067,
#       'value': 215},
#      'cancellations': {'period': '60 days', 'rate': 0.0001, 'value': 5}}}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#    'city': {'id': None, 'name': 'Ciudad Autonoma de Buenos Aires'}},
#   'address': {'state_id': 'AR-C',
#    'state_name': 'Capital Federal',
#    'city_id': None,
#    'city_name': 'Ciudad Autonoma de Buenos Aires'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '12174831',
#     'value_name': 'IKOSHOP',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '12174831',
#       'name': 'IKOSHOP',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': None,
#     'value_name': 'Cocina',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Cocina',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Set De Ollas',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Set De Ollas',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'}],
#   'variations_data': {'174064226355': {'thumbnail': 'http://http2.mlstatic.com/D_683347-MLA49275833629_032022-O.jpg',
#     'ratio': '1.66',
#     'name': 'Negro',
#     'pictures_qty': 10}},
#   'installments': {'quantity': 6,
#    'amount': 2410.69,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA856305306',
#   'title': 'Cacerola Teflón Antiadherente Hudson Nº 28 Con Tapa Vidrio',
#   'condition': 'new',
#   'thumbnail_id': '943745-MLA41862542498_052020',
#   'catalog_product_id': 'MLA19951390',
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-856305306-cacerola-teflon-antiadherente-hudson-n-28-con-tapa-vidrio-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_943745-MLA41862542498_052020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 8,
#   'price': 9350,
#   'original_price': 11000,
#   'sale_price': None,
#   'sold_quantity': 5,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_thumbnail',
#    'brand_verified',
#    'catalog_listing_eligible',
#    'good_quality_picture',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2040-05-13T04:00:00.000Z',
#   'seller': {'id': 357704483,
#    'nickname': 'SERBAZARES',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2018-09-25T21:56:19.000-04:00',
#    'tags': ['normal',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/SERBAZARES',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 542,
#      'completed': 10229,
#      'period': 'historic',
#      'ratings': {'negative': 0.04, 'neutral': 0.02, 'positive': 0.94},
#      'total': 10771},
#     'metrics': {'sales': {'period': '60 days', 'completed': 2307},
#      'claims': {'period': '60 days', 'rate': 0.0049, 'value': 12},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0898,
#       'value': 181},
#      'cancellations': {'period': '60 days', 'rate': 0.0058, 'value': 14}}},
#    'eshop': {'eshop_id': 397298,
#     'seller': 357704483,
#     'nick_name': 'SERBAZARES',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/357704483v46a907.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': 'TUxBQ0JFUjYyYWU3', 'name': 'Berazategui'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': 'TUxBQ0JFUjYyYWU3',
#    'city_name': 'Berazategui'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '2333684',
#     'value_name': 'Hudson',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2333684',
#       'name': 'Hudson',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'list'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Cacerola Aluminio',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Cacerola Aluminio',
#       'struct': None,
#       'source': 3376461333454861}],
#     'source': 3376461333454861,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359391',
#     'value_name': 'Unidad',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '1',
#       'struct': None,
#       'source': 3045741222775799}],
#     'source': 3045741222775799,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '-1',
#     'value_name': None,
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '-1',
#       'name': None,
#       'struct': None,
#       'source': 3376461333454861}],
#     'source': 3376461333454861,
#     'value_type': 'number_unit'}],
#   'variations_data': {'56188562735': {'thumbnail': 'http://http2.mlstatic.com/D_943745-MLA41862542498_052020-O.jpg',
#     'ratio': '1.72',
#     'name': 'Negro',
#     'pictures_qty': 5}},
#   'installments': {'quantity': 6,
#    'amount': 2311.79,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA874586798',
#   'title': 'Cacerola Honda Tramontina Grano Inox 24cm 5,8l C/tapa Y Asas',
#   'condition': 'new',
#   'thumbnail_id': '779430-MLA43234029328_082020',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-874586798-cacerola-honda-tramontina-grano-inox-24cm-58l-ctapa-y-asas-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_779430-MLA43234029328_082020-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 9,
#   'price': 39002.9,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 3,
#   'available_quantity': 50,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['brand_verified',
#    'good_quality_picture',
#    'good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2040-08-17T04:00:00.000Z',
#   'seller': {'id': 466221444,
#    'nickname': 'SAFGOL',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2019-08-29T17:59:08.000-04:00',
#    'tags': ['normal',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/MUGELLO+S.R.L',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 664,
#      'completed': 15453,
#      'period': 'historic',
#      'ratings': {'negative': 0.03, 'neutral': 0.01, 'positive': 0.96},
#      'total': 16117},
#     'metrics': {'sales': {'period': '60 days', 'completed': 2379},
#      'claims': {'period': '60 days', 'rate': 0.006, 'value': 15},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0294,
#       'value': 70},
#      'cancellations': {'period': '60 days', 'rate': 0.0036, 'value': 9}}},
#    'eshop': {'eshop_id': 389937,
#     'seller': 466221444,
#     'nick_name': 'SAFGOL',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/466221444v5922ff.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#    'city': {'id': 'TUxBQlNBTjkwNTZa', 'name': 'San Cristóbal'}},
#   'address': {'state_id': 'AR-C',
#    'state_name': 'Capital Federal',
#    'city_id': 'TUxBQlNBTjkwNTZa',
#    'city_name': 'San Cristóbal'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': None,
#     'value_name': 'Tramonina',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Tramonina',
#       'struct': None,
#       'source': 4954751883138633}],
#     'source': 4954751883138633,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 4954751883138633}],
#     'source': 4954751883138633,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': None,
#     'value_name': 'Granó',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Granó',
#       'struct': None,
#       'source': 1000427007642219}],
#     'source': 1000427007642219,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Grano',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Grano',
#       'struct': None,
#       'source': 4954751883138633}],
#     'source': 4954751883138633,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': '1359391',
#     'value_name': 'Unidad',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 4954751883138633}],
#     'source': 4954751883138633,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '1',
#       'struct': None,
#       'source': 4954751883138633}],
#     'source': 4954751883138633,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': None,
#     'value_name': '2.37 kg',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': {'number': 2.37, 'unit': 'kg'},
# ...
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '1359391',
#       'name': 'Unidad',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'string'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': '1',
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': '-1',
#     'value_name': None,
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '-1',
#       'name': None,
#       'struct': None,
#       'source': 6808261514773724}],
#     'source': 6808261514773724,
#     'value_type': 'number_unit'}],
#   'variations_data': {'89551961138': {'thumbnail': 'http://http2.mlstatic.com/D_647138-MLA46567492233_062021-O.jpg',
#     'ratio': '1.38',
#     'name': 'Negro',
#     'pictures_qty': 3}},
#   'installments': {'quantity': 6,
#    'amount': 2199.29,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA751439032',
#   'title': 'Olla Marmicoc Presion T09 Válvula De Seguridad 9 Litros',
#   'condition': 'new',
#   'thumbnail_id': '821127-MLA31352684187_072019',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-751439032-olla-marmicoc-presion-t09-valvula-de-seguridad-9-litros-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA9181',
#   'domain_id': 'MLA-KITCHEN_POTS',
#   'thumbnail': 'http://http2.mlstatic.com/D_821127-MLA31352684187_072019-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 48,
#   'price': 19999,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 500,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['brand_verified',
#    'dragged_bids_and_visits',
#    'good_quality_picture',
#    'good_quality_thumbnail',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2038-09-28T04:00:00.000Z',
#   'seller': {'id': 167571601,
#    'nickname': 'ELECTROYHOGAR1',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2014-09-26T09:51:53.000-04:00',
#    'tags': ['normal',
#     'credits_priority_4',
#     'eshop',
#     'mshops',
#     'credits_profile',
#     'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/WWW.ELECTROYHOGAR.COM.AR',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 6081,
#      'completed': 75701,
#      'period': 'historic',
#      'ratings': {'negative': 0.06, 'neutral': 0.04, 'positive': 0.9},
#      'total': 81782},
#     'metrics': {'sales': {'period': '60 days', 'completed': 14966},
#      'claims': {'period': '60 days', 'rate': 0.0117, 'value': 188},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0039,
#       'value': 55},
#      'cancellations': {'period': '60 days', 'rate': 0.0076, 'value': 123}}},
#    'eshop': {'eshop_id': 176625,
#     'seller': 167571601,
#     'nick_name': 'ELECTROYHOGAR1',
#     'eshop_status_id': 1,
#     'site_id': 'MLA',
#     'eshop_experience': 0,
#     'eshop_rubro': None,
#     'eshop_locations': [],
#     'eshop_logo_url': 'http://http2.mlstatic.com/eshops-logo/167571601vafbd94.png'}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': 'TUxBV2lsZGU', 'name': 'Wilde'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': 'TUxBV2lsZGU',
#    'city_name': 'Wilde'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '2373769',
#     'value_name': 'Marmicoc',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2373769',
#       'name': 'Marmicoc',
#       'struct': None,
#       'source': 17405550362297}],
#     'source': 17405550362297,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 1572}],
#     'source': 1572,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': None,
#     'value_name': 'marmicoc',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'marmicoc',
#       'struct': None,
#       'source': 17405550362297}],
#     'source': 17405550362297,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'T09',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None, 'name': 'T09', 'struct': None, 'source': 1572}],
#     'source': 1572,
#     'value_type': 'string'},
#    {'id': 'SALE_FORMAT',
#     'name': 'Formato de venta',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None, 'name': '1', 'struct': None, 'source': 1572}],
#     'source': 1572,
#     'value_type': 'list'},
#    {'id': 'UNITS_PER_PACK',
#     'name': 'Unidades por pack',
#     'value_id': None,
#     'value_name': '1',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None, 'name': '1', 'struct': None, 'source': 1572}],
#     'source': 1572,
#     'value_type': 'number'},
#    {'id': 'WEIGHT',
#     'name': 'Peso',
#     'value_id': None,
#     'value_name': '3 kg',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': {'number': 3, 'unit': 'kg'},
#     'values': [{'id': None,
#       'name': '3 kg',
#       'struct': {'number': 3, 'unit': 'kg'},
#       'source': 1572}],
#     'source': 1572,
#     'value_type': 'number_unit'}],
#   'variations_data': {'34916500748': {'thumbnail': 'http://http2.mlstatic.com/D_821127-MLA31352684187_072019-O.jpg',
#     'ratio': '1.11',
#     'name': 'Plateado',
#     'pictures_qty': 5}},
#   'installments': {'quantity': 6,
#    'amount': 4944.75,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA905974983',
#   'title': 'Olla Pochoclera Silicona Pop Corn Para Microondas 4 Mins!!!',
#   'condition': 'new',
#   'thumbnail_id': '620640-MLA52429216758_112022',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_special',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-905974983-olla-pochoclera-silicona-pop-corn-para-microondas-4-mins-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA418359',
#   'domain_id': 'MLA-STOVETOP_POPCORN_POPPERS',
#   'thumbnail': 'http://http2.mlstatic.com/D_620640-MLA52429216758_112022-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 49,
#   'price': 4340,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 50,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['loyalty_discount_eligible',
#    'brand_verified',
#    'good_quality_picture',
#    'good_quality_thumbnail',
#    'immediate_payment',
#    'cart_eligible',
#    'shipping_guaranteed'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': False,
#    'tags': ['self_service_in'],
#    'promise': None},
#   'stop_time': '2041-01-22T04:00:00.000Z',
#   'seller': {'id': 331490603,
#    'nickname': 'FEEL BAZAR',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2018-06-27T15:56:44.000-04:00',
#    'tags': ['normal', 'mshops', 'credits_profile', 'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/FEEL+BAZAR',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 926,
#      'completed': 24969,
#      'period': 'historic',
#      'ratings': {'negative': 0.02, 'neutral': 0.02, 'positive': 0.96},
#      'total': 25895},
#     'metrics': {'sales': {'period': '60 days', 'completed': 3972},
#      'claims': {'period': '60 days', 'rate': 0.0048, 'value': 20},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0188,
#       'value': 74},
#      'cancellations': {'period': '60 days', 'rate': 0.0024, 'value': 10}}}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#    'city': {'id': 'TUxBQkJFTDcyNTJa', 'name': 'Belgrano'}},
#   'address': {'state_id': 'AR-C',
#    'state_name': 'Capital Federal',
#    'city_id': 'TUxBQkJFTDcyNTJa',
#    'city_name': 'Belgrano'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': None,
#     'value_name': 'feel',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'feel',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'silicona',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'silicona',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'}],
#   'variations_data': {'74268827940': {'thumbnail': 'http://http2.mlstatic.com/D_620640-MLA52429216758_112022-O.jpg',
#     'ratio': '0.88',
#     'name': 'Rojo',
#     'pictures_qty': 8}},
#   'installments': {'quantity': 6,
#    'amount': 1073.07,
#    'rate': 48.35,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'inventory_id': None},
#  {'id': 'MLA905426642',
#   'title': 'Set De 2 Ollas Sartén Panquequera Bifera Wok Hudson Teflon',
#   'condition': 'new',
#   'thumbnail_id': '704157-MLA44692167823_012021',
#   'catalog_product_id': None,
#   'listing_type_id': 'gold_pro',
#   'permalink': 'https://articulo.mercadolibre.com.ar/MLA-905426642-set-de-2-ollas-sarten-panquequera-bifera-wok-hudson-teflon-_JM',
#   'buying_mode': 'buy_it_now',
#   'site_id': 'MLA',
#   'category_id': 'MLA30098',
#   'domain_id': 'MLA-KITCHEN_COOKWARE_SETS',
#   'thumbnail': 'http://http2.mlstatic.com/D_704157-MLA44692167823_012021-I.jpg',
#   'currency_id': 'ARS',
#   'order_backend': 50,
#   'price': 50876.45,
#   'original_price': None,
#   'sale_price': None,
#   'sold_quantity': 5,
#   'available_quantity': 1,
#   'official_store_id': None,
#   'use_thumbnail_id': True,
#   'accepts_mercadopago': True,
#   'tags': ['good_quality_picture',
#    'good_quality_thumbnail',
#    'loyalty_discount_eligible',
#    '3x_campaign',
#    'brand_verified',
#    'immediate_payment',
#    'cart_eligible'],
#   'variation_filters': ['COLOR'],
#   'shipping': {'logistic_type': 'cross_docking',
#    'mode': 'me2',
#    'store_pick_up': False,
#    'free_shipping': True,
#    'tags': ['self_service_in', 'mandatory_free_shipping'],
#    'promise': None},
#   'stop_time': '2041-01-19T04:00:00.000Z',
#   'seller': {'id': 414366803,
#    'nickname': 'GRUPOJENASA',
#    'car_dealer': False,
#    'real_estate_agency': False,
#    'registration_date': '2019-03-08T14:38:51.000-04:00',
#    'tags': ['normal', 'credits_profile', 'mshops', 'messages_as_seller'],
#    'car_dealer_logo': '',
#    'permalink': 'http://perfil.mercadolibre.com.ar/GRUPOJENASA',
#    'seller_reputation': {'level_id': '5_green',
#     'power_seller_status': 'platinum',
#     'transactions': {'canceled': 583,
#      'completed': 10705,
#      'period': 'historic',
#      'ratings': {'negative': 0.08, 'neutral': 0.02, 'positive': 0.9},
#      'total': 11288},
#     'metrics': {'sales': {'period': '60 days', 'completed': 1902},
#      'claims': {'period': '60 days', 'rate': 0.0104, 'value': 21},
#      'delayed_handling_time': {'period': '60 days',
#       'rate': 0.0182,
#       'value': 35},
#      'cancellations': {'period': '60 days', 'rate': 0, 'value': 2}}}},
#   'seller_address': {'comment': '',
#    'address_line': '',
#    'zip_code': '',
#    'id': None,
#    'latitude': None,
#    'longitude': None,
#    'country': {'id': 'AR', 'name': 'Argentina'},
#    'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#    'city': {'id': None, 'name': 'Canning'}},
#   'address': {'state_id': 'AR-B',
#    'state_name': 'Buenos Aires',
#    'city_id': None,
#    'city_name': 'Canning'},
#   'attributes': [{'id': 'BRAND',
#     'name': 'Marca',
#     'value_id': '2333684',
#     'value_name': 'Hudson',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2333684',
#       'name': 'Hudson',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'ITEM_CONDITION',
#     'name': 'Condición del ítem',
#     'value_id': '2230284',
#     'value_name': 'Nuevo',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': '2230284',
#       'name': 'Nuevo',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'list'},
#    {'id': 'LINE',
#     'name': 'Línea',
#     'value_id': None,
#     'value_name': 'Teflón antiadherente',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Teflón antiadherente',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'},
#    {'id': 'MODEL',
#     'name': 'Modelo',
#     'value_id': None,
#     'value_name': 'Aluminio de 2,1 mm de espesor',
#     'attribute_group_id': 'OTHERS',
#     'attribute_group_name': 'Otros',
#     'value_struct': None,
#     'values': [{'id': None,
#       'name': 'Aluminio de 2,1 mm de espesor',
#       'struct': None,
#       'source': 2860837171021627}],
#     'source': 2860837171021627,
#     'value_type': 'string'}],
#   'variations_data': {'73983882714': {'thumbnail': 'http://http2.mlstatic.com/D_704157-MLA44692167823_012021-O.jpg',
#     'ratio': '1.33',
#     'name': 'Azul',
#     'pictures_qty': 1},
#    '73983882710': {'thumbnail': 'http://http2.mlstatic.com/D_822076-MLA44692168818_012021-O.jpg',
#     'ratio': '1.33',
#     'name': 'Negro',
#     'pictures_qty': 2}},
#   'installments': {'quantity': 3,
#    'amount': 16958.82,
#    'rate': 0,
#    'currency_id': 'ARS'},
#   'winner_item_id': None,
#   'discounts': None,
#   'promotions': None,
#   'differential_pricing': {'id': 35713320},
#   'inventory_id': None}]

# %%
import pandas as pd

data = pd.DataFrame(r.json()['results'])
data
# Out:
#                id                                              title  \
# 0    MLA929609347  Cacerola Tefal Pratika 24 Cm Olla Tapa Vidrio ...
# 1    MLA852054216  Olla Pochoclera  Familiar Jovifel Con Cuchara ...
# 2   MLA1100832118  Bateria De Cocina Set Ollas Allegra 4 Pzs Tram...
# 3    MLA901025302  Juego De Ollas Set De 4 Piezas Tramontina Alle...
# 4   MLA1302524260       Cacerola Hudson Antiadherente Ceramico 24 Cm
# 5    MLA886153965      Cacerola Antiadherente Hudson  26 Cm Aluminio
# 6   MLA1118109454  Set 7 Piezas Cocina Bateria Ollas Cacerola Sar...
# 7    MLA856305306  Cacerola Teflón Antiadherente Hudson Nº 28 Con...
# 8    MLA874586798  Cacerola Honda Tramontina Grano Inox 24cm 5,8l...
# 9    MLA826585754  Olla A Presion Panelux 10 Litros Aluminio Puli...
# 10   MLA907396064  Bateria Cocina Hudson Ceramica 5 Pzs Apta Indu...
# 11   MLA926396334  Cacerola Gastronómica Nº30 Aluminio Almandoz R...
# 12  MLA1320262192  Cacerola Hierro, Horno Holandés, Tapa Sarten, ...
# 13  MLA1143506166  Batería De Cocina Aluminio Brinox Masala 7 Piezas
# 14   MLA725489092  Paellera 32 Cm Con Teflon Antiadherente Doña T...
# 15   MLA874725966  Cacerola Tramontina Grano Inox T/tapa Y Asas 2...
# 16  MLA1152587851  Juego Ollas Cocina Kit Antiadherente + Bowl + ...
# 17  MLA1281450187  Batería Hudson Juego Set Cocina Cerámica Cubie...
# 18   MLA869242718  Olla/wok+ Sarten Hierro Fundido C/mango Doble ...
# 19   MLA903437929  Cacerola Gastronómica De Aluminio N° 22 Capaci...
# 20  MLA1113070567  Bateria Cocina 7p Tramontina Olla Cacerola Sar...
# 21   MLA637819602  Pochoclera Familiar Olla Aluminio Hogareña P H...
# 22  MLA1276960420  Cacerola Hudson Antiadherente Induccion 28 Cm ...
# 23   MLA785914999  Cacerola Olla 25 Cm Aluminio Sin Teflon Doña T...
# 24  MLA1103740127  Bateria 7 Piezas Induccion Hudson 4mm Wok Jarr...
# 25   MLA882652710  Cacerola Cerámica 24cm Inducción Alum. Forjado...
# 26   MLA876923428             Olla Aluminio Nro 34 C/tapa Cerveceros
# 27   MLA620054578    Plancha Bifera En Hierro 3,2 Mm Directo Fabrica
# 28  MLA1143554220   Batería De Cocina Aluminio Brinox Ebony 5 Piezas
# 29  MLA1117909521  Cacerola Tramontina Solar 62501/240 Con Mango ...
# 30  MLA1124004308  Olla Cacerola 24cm Antiadherente Pixel Pro 4.2...
# 31   MLA933070317  Set Bateria Cocina X4 Piezas Tramontina Loreto...
# 32  MLA1277654162  Olla Acero Inox 18cm Antiadherente Inducción T...
# 33   MLA833186358  Olla Alta Tramontina Triple Fondo Solar Pastas...
# 34   MLA862008040  Cacerola Antiadherente Nº24 - 4,5 Lts - Jovife...
# 35  MLA1139213911  Set Ollas Sarten Granito Jarr Bif Panq Hudson ...
# 36   MLA864435031  Cacerola Gastronómica  C/ Tapa De Aluminio 50 ...
# 37   MLA885446083  Cacerola Paris Tramontina 20cm Antiadherente T...
# 38   MLA875545594  Juego De Ollas Bateria Cocina Tramontina Turim...
# 39   MLA922696090  Olla Cacerola Asas 24cm Cerámica Tv Porcelana ...
# 40  MLA1113353772        Cacerola Loreto 22cm Tapa Vidrio Tramontina
# 41   MLA870445691             Olla Alum Nro 45 (70l) C/tapa  Cerveza
# 42  MLA1102833792  Bateria De Cocina + Pizzera Tramontina Loreto ...
# 43  MLA1313173328  Cacerola Olla Acero Antiadherente 20 Tapa Vidr...
# 44   MLA911630746   Pochoclera Pororó Olla 3,6 Lts Con Teflón Mta Ct
# 45  MLA1131718212  Bateria De Cocina Tramontina Ventura 4 Piezas ...
# 46   MLA927686623  Olla De Aluminio Antiadherente 22 Cm Con Tapa ...
# 47   MLA751439032  Olla Marmicoc Presion T09 Válvula De Seguridad...
# 48   MLA905974983  Olla Pochoclera Silicona Pop Corn Para Microon...
# 49   MLA905426642  Set De 2 Ollas Sartén Panquequera Bifera Wok H...
#
#    condition                  thumbnail_id catalog_product_id listing_type_id  \
# 0        new  955634-MLA47654284358_092021         MLA8933515    gold_special
# 1        new  776761-MLA41931585076_052020               None    gold_special
# 2        new  908941-MLA47322367522_092021               None    gold_special
# 3        new  963503-MLA44331302075_122020        MLA20025885    gold_special
# 4        new  883315-MLA41808510636_052020        MLA19944340    gold_special
# 5        new  771831-MLA43953771320_102020        MLA19944327        gold_pro
# 6        new  683347-MLA49275833629_032022               None    gold_special
# 7        new  943745-MLA41862542498_052020        MLA19951390    gold_special
# 8        new  779430-MLA43234029328_082020               None    gold_special
# 9        new  600217-MLA32955855005_112019        MLA10936086    gold_special
# 10       new  934567-MLA46235692438_062021               None    gold_special
# 11       new  954116-MLA46454518227_062021               None        gold_pro
# 12       new  732059-MLA42010026216_052020        MLA21234492    gold_special
# 13       new  907406-MLA50409440427_062022               None    gold_special
# 14       new  663454-MLA49684234394_042022               None    gold_special
# 15       new  962818-MLA43240402120_082020               None        gold_pro
# 16       new  845420-MLA53640840734_022023               None    gold_special
# 17       new  662690-MLA53594723363_022023               None    gold_special
# 18       new  974008-MLA53014587108_122022               None    gold_special
# 19       new  727063-MLA44515188393_012021        MLA11181299    gold_special
# 20       new  623005-MLA31353318805_072019               None    gold_special
# 21       new  112905-MLA25087793097_102016               None    gold_special
# 22       new  939654-MLA42969257039_082020        MLA19944371    gold_special
# 23       new  760156-MLA43193069865_082020               None    gold_special
# 24       new  849643-MLA46182640642_052021               None    gold_special
# 25       new  999081-MLA45143026383_032021        MLA19944323    gold_special
# 26       new  608922-MLA46277359089_062021               None    gold_special
# 27       new  940290-MLA31043215703_062019               None    gold_special
# 28       new  940723-MLA50409254147_062022               None    gold_special
# 29       new  945251-MLA49771794163_042022        MLA10892482    gold_special
# 30       new  841407-MLA49142836538_022022               None    gold_special
# 31       new  915744-MLA53099421704_122022               None    gold_special
# 32       new  866125-MLA49707704051_042022        MLA19951397    gold_special
# 33       new  933290-MLA49771328142_042022        MLA10892484    gold_special
# 34       new  660250-MLA42186038845_062020        MLA20044814    gold_special
# 35       new  626012-MLA50111502647_052022               None        gold_pro
# 36       new  620932-MLA46247331524_062021        MLA11181299    gold_special
# 37       new  832382-MLA43876215523_102020               None    gold_special
# 38       new  700717-MLA45793904778_052021               None        gold_pro
# 39       new  843396-MLA46184904706_052021        MLA21216008    gold_special
# 40       new  815853-MLA48494257993_122021        MLA19978876    gold_special
# 41       new  907673-MLA42036102663_062020               None    gold_special
# 42       new  710136-MLA47452674825_092021               None    gold_special
# 43       new  844595-MLA46008047165_052021        MLA19978953    gold_special
# 44       new  799340-MLA49837222504_052022               None        gold_pro
# 45       new  683873-MLA49771827060_042022               None        gold_pro
# 46       new  647138-MLA46567492233_062021               None    gold_special
# 47       new  821127-MLA31352684187_072019               None    gold_special
# 48       new  620640-MLA52429216758_112022               None    gold_special
# 49       new  704157-MLA44692167823_012021               None        gold_pro
#
#                                             permalink buying_mode site_id  \
# 0   https://articulo.mercadolibre.com.ar/MLA-92960...  buy_it_now     MLA
# 1   https://articulo.mercadolibre.com.ar/MLA-85205...  buy_it_now     MLA
# 2   https://articulo.mercadolibre.com.ar/MLA-11008...  buy_it_now     MLA
# 3   https://articulo.mercadolibre.com.ar/MLA-90102...  buy_it_now     MLA
# 4   https://www.mercadolibre.com.ar/cacerola-hudso...  buy_it_now     MLA
# 5   https://articulo.mercadolibre.com.ar/MLA-88615...  buy_it_now     MLA
# 6   https://articulo.mercadolibre.com.ar/MLA-11181...  buy_it_now     MLA
# 7   https://articulo.mercadolibre.com.ar/MLA-85630...  buy_it_now     MLA
# 8   https://articulo.mercadolibre.com.ar/MLA-87458...  buy_it_now     MLA
# 9   https://articulo.mercadolibre.com.ar/MLA-82658...  buy_it_now     MLA
# 10  https://articulo.mercadolibre.com.ar/MLA-90739...  buy_it_now     MLA
# 11  https://articulo.mercadolibre.com.ar/MLA-92639...  buy_it_now     MLA
# 12  https://www.mercadolibre.com.ar/cacerola-hierr...  buy_it_now     MLA
# 13  https://articulo.mercadolibre.com.ar/MLA-11435...  buy_it_now     MLA
# 14  https://articulo.mercadolibre.com.ar/MLA-72548...  buy_it_now     MLA
# 15  https://articulo.mercadolibre.com.ar/MLA-87472...  buy_it_now     MLA
# 16  https://articulo.mercadolibre.com.ar/MLA-11525...  buy_it_now     MLA
# 17  https://articulo.mercadolibre.com.ar/MLA-12814...  buy_it_now     MLA
# 18  https://articulo.mercadolibre.com.ar/MLA-86924...  buy_it_now     MLA
# 19  https://articulo.mercadolibre.com.ar/MLA-90343...  buy_it_now     MLA
# 20  https://articulo.mercadolibre.com.ar/MLA-11130...  buy_it_now     MLA
# 21  https://articulo.mercadolibre.com.ar/MLA-63781...  buy_it_now     MLA
# 22  https://www.mercadolibre.com.ar/cacerola-hudso...  buy_it_now     MLA
# 23  https://articulo.mercadolibre.com.ar/MLA-78591...  buy_it_now     MLA
# 24  https://articulo.mercadolibre.com.ar/MLA-11037...  buy_it_now     MLA
# 25  https://articulo.mercadolibre.com.ar/MLA-88265...  buy_it_now     MLA
# 26  https://articulo.mercadolibre.com.ar/MLA-87692...  buy_it_now     MLA
# 27  https://articulo.mercadolibre.com.ar/MLA-62005...  buy_it_now     MLA
# 28  https://articulo.mercadolibre.com.ar/MLA-11435...  buy_it_now     MLA
# 29  https://articulo.mercadolibre.com.ar/MLA-11179...  buy_it_now     MLA
# 30  https://articulo.mercadolibre.com.ar/MLA-11240...  buy_it_now     MLA
# 31  https://articulo.mercadolibre.com.ar/MLA-93307...  buy_it_now     MLA
# 32  https://www.mercadolibre.com.ar/olla-acero-ino...  buy_it_now     MLA
# 33  https://articulo.mercadolibre.com.ar/MLA-83318...  buy_it_now     MLA
# 34  https://articulo.mercadolibre.com.ar/MLA-86200...  buy_it_now     MLA
# 35  https://articulo.mercadolibre.com.ar/MLA-11392...  buy_it_now     MLA
# 36  https://articulo.mercadolibre.com.ar/MLA-86443...  buy_it_now     MLA
# 37  https://articulo.mercadolibre.com.ar/MLA-88544...  buy_it_now     MLA
# 38  https://articulo.mercadolibre.com.ar/MLA-87554...  buy_it_now     MLA
# 39  https://articulo.mercadolibre.com.ar/MLA-92269...  buy_it_now     MLA
# 40  https://articulo.mercadolibre.com.ar/MLA-11133...  buy_it_now     MLA
# 41  https://articulo.mercadolibre.com.ar/MLA-87044...  buy_it_now     MLA
# 42  https://articulo.mercadolibre.com.ar/MLA-11028...  buy_it_now     MLA
# 43  https://www.mercadolibre.com.ar/cacerola-olla-...  buy_it_now     MLA
# 44  https://articulo.mercadolibre.com.ar/MLA-91163...  buy_it_now     MLA
# 45  https://articulo.mercadolibre.com.ar/MLA-11317...  buy_it_now     MLA
# 46  https://articulo.mercadolibre.com.ar/MLA-92768...  buy_it_now     MLA
# 47  https://articulo.mercadolibre.com.ar/MLA-75143...  buy_it_now     MLA
# 48  https://articulo.mercadolibre.com.ar/MLA-90597...  buy_it_now     MLA
# 49  https://articulo.mercadolibre.com.ar/MLA-90542...  buy_it_now     MLA
#
#    category_id  ...                                            address  \
# 0      MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 1    MLA418359  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 2     MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 3      MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 4      MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 5      MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 6     MLA30098  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 7      MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 8      MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 9      MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 10    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 11     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 12     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 13    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 14   MLA418351  ...  {'state_id': 'AR-S', 'state_name': 'Santa Fe',...
# 15     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 16     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 17    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 18   MLA375459  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 19     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 20    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 21   MLA418359  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 22     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 23     MLA9181  ...  {'state_id': 'AR-S', 'state_name': 'Santa Fe',...
# 24    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 25     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 26     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 27    MLA78318  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 28    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 29     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 30     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 31    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 32     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 33     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 34     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 35    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 36     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 37     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 38    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 39     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 40     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 41     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 42    MLA30098  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 43     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 44   MLA418359  ...  {'state_id': 'AR-S', 'state_name': 'Santa Fe',...
# 45    MLA30098  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 46     MLA9181  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 47     MLA9181  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
# 48   MLA418359  ...  {'state_id': 'AR-C', 'state_name': 'Capital Fe...
# 49    MLA30098  ...  {'state_id': 'AR-B', 'state_name': 'Buenos Air...
#
#                                            attributes  \
# 0   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 1   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 2   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 3   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 4   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 5   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 6   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 7   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 8   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 9   [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 10  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 11  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 12  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 13  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 14  [{'id': 'SALE_FORMAT', 'name': 'Formato de ven...
# 15  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 16  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 17  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 18  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 19  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 20  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 21  [{'id': 'SALE_FORMAT', 'name': 'Formato de ven...
# 22  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 23  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 24  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 25  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 26  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 27  [{'id': 'SALE_FORMAT', 'name': 'Formato de ven...
# 28  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 29  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 30  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 31  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 32  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 33  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 34  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 35  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 36  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 37  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 38  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 39  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 40  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 41  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 42  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 43  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 44  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 45  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 46  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 47  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 48  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
# 49  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...
#
#                                       variations_data  \
# 0   {'91192319346': {'thumbnail': 'http://http2.ml...
# 1   {'54812961542': {'thumbnail': 'http://http2.ml...
# 2   {'173566020143': {'thumbnail': 'http://http2.m...
# 3   {'70654086992': {'thumbnail': 'http://http2.ml...
# 4                                                 NaN
# 5   {'67140466032': {'thumbnail': 'http://http2.ml...
# 6   {'174064226355': {'thumbnail': 'http://http2.m...
# 7   {'56188562735': {'thumbnail': 'http://http2.ml...
# 8   {'62388608869': {'thumbnail': 'http://http2.ml...
# 9   {'46770986091': {'thumbnail': 'http://http2.ml...
# 10  {'173767784491': {'thumbnail': 'http://http2.m...
# 11  {'88532664153': {'thumbnail': 'http://http2.ml...
# 12                                                NaN
# 13  {'174686167904': {'thumbnail': 'http://http2.m...
# 14  {'58824689456': {'thumbnail': 'http://http2.ml...
# 15  {'62430605682': {'thumbnail': 'http://http2.ml...
# 16  {'175021116236': {'thumbnail': 'http://http2.m...
# 17  {'176119524605': {'thumbnail': 'http://http2.m...
# 18  {'60396981477': {'thumbnail': 'http://http2.ml...
# 19  {'72522436282': {'thumbnail': 'http://http2.ml...
# 20  {'173926525352': {'thumbnail': 'http://http2.m...
# 21  {'32253981429': {'thumbnail': 'http://http2.ml...
# 22                                                NaN
# 23  {'58826547383': {'thumbnail': 'http://http2.ml...
# 24  {'173665562739': {'thumbnail': 'http://http2.m...
# 25  {'65479346006': {'thumbnail': 'http://http2.ml...
# 26  {'63429111714': {'thumbnail': 'http://http2.ml...
# 27  {'40236462703': {'thumbnail': 'http://http2.ml...
# 28  {'174685860212': {'thumbnail': 'http://http2.m...
# 29  {'176478576209': {'thumbnail': 'http://http2.m...
# 30  {'174212582593': {'thumbnail': 'http://http2.m...
# 31  {'93439099785': {'thumbnail': 'http://http2.ml...
# 32                                                NaN
# 33  {'48807224147': {'thumbnail': 'http://http2.ml...
# 34  {'57923389013': {'thumbnail': 'http://http2.ml...
# 35  {'174571169209': {'thumbnail': 'http://http2.m...
# 36  {'58727133590': {'thumbnail': 'http://http2.ml...
# 37  {'66754128455': {'thumbnail': 'http://http2.ml...
# 38  {'83550294265': {'thumbnail': 'http://http2.ml...
# 39  {'86097972769': {'thumbnail': 'http://http2.ml...
# 40  {'173935225159': {'thumbnail': 'http://http2.m...
# 41  {'60822832455': {'thumbnail': 'http://http2.ml...
# 42  {'173624522892': {'thumbnail': 'http://http2.m...
# 43                                                NaN
# 44  {'78592651611': {'thumbnail': 'http://http2.ml...
# 45                                                NaN
# 46  {'89551961138': {'thumbnail': 'http://http2.ml...
# 47  {'34916500748': {'thumbnail': 'http://http2.ml...
# 48  {'74268827940': {'thumbnail': 'http://http2.ml...
# 49  {'73983882714': {'thumbnail': 'http://http2.ml...
#
#                                          installments  winner_item_id  \
# 0   {'quantity': 6, 'amount': 3139.83, 'rate': 48....            None
# 1   {'quantity': 6, 'amount': 1176.66, 'rate': 48....            None
# 2   {'quantity': 6, 'amount': 11402.92, 'rate': 48...            None
# 3   {'quantity': 6, 'amount': 12386.98, 'rate': 48...            None
# 4   {'quantity': 6, 'amount': 2113.74, 'rate': 48....            None
# 5   {'quantity': 6, 'amount': 1746.67, 'rate': 0, ...            None
# 6   {'quantity': 6, 'amount': 2410.69, 'rate': 48....            None
# 7   {'quantity': 6, 'amount': 2311.79, 'rate': 48....            None
# 8   {'quantity': 6, 'amount': 9643.47, 'rate': 48....            None
# 9   {'quantity': 6, 'amount': 4025.23, 'rate': 48....            None
# 10  {'quantity': 6, 'amount': 5130.44, 'rate': 48....            None
# 11  {'quantity': 3, 'amount': 3153.33, 'rate': 0, ...            None
# 12  {'quantity': 6, 'amount': 1977.51, 'rate': 48....            None
# 13  {'quantity': 6, 'amount': 7397.5, 'rate': 48.3...            None
# 14  {'quantity': 6, 'amount': 5179.89, 'rate': 48....            None
# 15  {'quantity': 6, 'amount': 7206.34, 'rate': 0, ...            None
# 16  {'quantity': 6, 'amount': 8159.25, 'rate': 48....            None
# 17  {'quantity': 6, 'amount': 5414.78, 'rate': 48....            None
# 18  {'quantity': 6, 'amount': 4450.25, 'rate': 48....            None
# 19  {'quantity': 6, 'amount': 823.1, 'rate': 48.35...            None
# 20  {'quantity': 6, 'amount': 11286.21, 'rate': 48...            None
# 21  {'quantity': 6, 'amount': 763.76, 'rate': 48.3...            None
# 22  {'quantity': 6, 'amount': 2801.1, 'rate': 48.3...            None
# 23  {'quantity': 6, 'amount': 3706.28, 'rate': 48....            None
# 24  {'quantity': 6, 'amount': 7158.85, 'rate': 48....            None
# 25  {'quantity': 6, 'amount': 2776.37, 'rate': 48....            None
# 26  {'quantity': 6, 'amount': 3585.12, 'rate': 48....            None
# 27  {'quantity': 6, 'amount': 1211.53, 'rate': 48....            None
# 28  {'quantity': 6, 'amount': 5439.25, 'rate': 48....            None
# 29  {'quantity': 6, 'amount': 4200.78, 'rate': 48....            None
# 30  {'quantity': 6, 'amount': 2163.19, 'rate': 48....            None
# 31  {'quantity': 6, 'amount': 5466.45, 'rate': 48....            None
# 32  {'quantity': 6, 'amount': 2583.52, 'rate': 48....            None
# 33  {'quantity': 6, 'amount': 5684.28, 'rate': 48....            None
# 34  {'quantity': 6, 'amount': 1854.13, 'rate': 48....            None
# 35  {'quantity': 3, 'amount': 23495.07, 'rate': 0,...            None
# 36  {'quantity': 6, 'amount': 5909.03, 'rate': 48....            None
# 37  {'quantity': 6, 'amount': 1975.28, 'rate': 48....            None
# 38  {'quantity': 6, 'amount': 6090, 'rate': 0, 'cu...            None
# 39  {'quantity': 6, 'amount': 2290.85, 'rate': 48....            None
# 40  {'quantity': 6, 'amount': 2420.38, 'rate': 48....            None
# 41  {'quantity': 6, 'amount': 6923, 'rate': 48.35,...            None
# 42  {'quantity': 6, 'amount': 10096.7, 'rate': 48....            None
# 43  {'quantity': 6, 'amount': 703.43, 'rate': 48.3...            None
# 44  {'quantity': 6, 'amount': 2155.83, 'rate': 0, ...            None
# 45  {'quantity': 6, 'amount': 6348.17, 'rate': 0, ...            None
# 46  {'quantity': 6, 'amount': 2199.29, 'rate': 48....            None
# 47  {'quantity': 6, 'amount': 4944.75, 'rate': 48....            None
# 48  {'quantity': 6, 'amount': 1073.07, 'rate': 48....            None
# 49  {'quantity': 3, 'amount': 16958.82, 'rate': 0,...            None
#
#     discounts promotions  inventory_id  catalog_listing  differential_pricing
# 0        None       None          None              NaN                   NaN
# 1        None       None          None              NaN                   NaN
# 2        None       None          None              NaN                   NaN
# 3        None       None          None              NaN                   NaN
# 4        None       None          None             True                   NaN
# 5        None       None          None              NaN      {'id': 33678187}
# 6        None       None          None              NaN                   NaN
# 7        None       None          None              NaN                   NaN
# 8        None       None          None              NaN                   NaN
# 9        None       None          None              NaN                   NaN
# 10       None       None          None              NaN                   NaN
# 11       None       None          None              NaN      {'id': 35713320}
# 12       None       None          None             True                   NaN
# 13       None       None          None              NaN                   NaN
# 14       None       None          None              NaN                   NaN
# 15       None       None          None              NaN      {'id': 33678187}
# 16       None       None          None              NaN                   NaN
# 17       None       None          None              NaN                   NaN
# 18       None       None          None              NaN                   NaN
# 19       None       None          None              NaN                   NaN
# 20       None       None          None              NaN                   NaN
# 21       None       None          None              NaN                   NaN
# 22       None       None          None             True                   NaN
# 23       None       None          None              NaN                   NaN
# 24       None       None          None              NaN                   NaN
# 25       None       None          None              NaN                   NaN
# 26       None       None          None              NaN                   NaN
# 27       None       None          None              NaN                   NaN
# 28       None       None          None              NaN                   NaN
# 29       None       None          None              NaN                   NaN
# 30       None       None          None              NaN                   NaN
# 31       None       None          None              NaN                   NaN
# 32       None       None          None             True                   NaN
# 33       None       None          None              NaN                   NaN
# 34       None       None          None              NaN                   NaN
# 35       None       None          None              NaN      {'id': 35713320}
# 36       None       None          None              NaN                   NaN
# 37       None       None          None              NaN                   NaN
# 38       None       None          None              NaN      {'id': 33678187}
# 39       None       None          None              NaN                   NaN
# 40       None       None          None              NaN                   NaN
# 41       None       None          None              NaN                   NaN
# 42       None       None          None              NaN                   NaN
# 43       None       None          None             True                   NaN
# 44       None       None          None              NaN      {'id': 33678187}
# 45       None       None          None              NaN      {'id': 33678187}
# 46       None       None          None              NaN                   NaN
# 47       None       None          None              NaN                   NaN
# 48       None       None          None              NaN                   NaN
# 49       None       None          None              NaN      {'id': 35713320}
#
# [50 rows x 38 columns]

# %%
datos = []
for i in tqdm(range(1000)):
    url = f"https://api.mercadolibre.com/items/MLA914459{i}/"
    r = requests.get(url)
    datos.append(r.json())
# Out:
# 100%|██████████| 1000/1000 [03:18<00:00,  5.04it/s]

# %%
import pandas as pd

# %%
data = pd.DataFrame(datos)

# %%
data
# Out:
#              id site_id                                              title  \
# 0  MLA914459980     MLA                Set De Mesas Nordicas Pua Laqueadas
# 1  MLA914459981     MLA                               Bicicleta Para Niños
# 2  MLA914459982     MLA         Pack Laur- 2 Pastas Y Aceitunas Con Carozo
# 3  MLA914459983     MLA       Samsung Galaxy S8+ 64 Gb Azul Coral 4 Gb Ram
# 4  MLA914459984     MLA                               Proyector Epson W18+
# 5  MLA914459985     MLA                                   Velas Aromáticas
# 6  MLA914459986     MLA          Campera Uniqlo Kids  Talle 9-10 Años Azul
# 7  MLA914459987     MLA                  Cable Conversor Vga A Hdmi Nuevo!
# 8  MLA914459988     MLA  Cargador Qi Inalámbrico - Ideal Para iPhone 8 ...
# 9  MLA914459989     MLA  Ark Survival Evolved Español | Pc Digital | Te...
#
#    subtitle  seller_id category_id  official_store_id    price  base_price  \
# 0       NaN  225484575     MLA4749                NaN   8500.0      8500.0
# 1       NaN  234057711     MLA4518                NaN  25000.0     25000.0
# 2       NaN  543155490    MLA40992                NaN    909.0       909.0
# 3       NaN   23089907     MLA1055                NaN  25000.0     25000.0
# 4       NaN  202997026    MLA11889                NaN  49999.0     49999.0
# 5       NaN  134752325    MLA31341                NaN    450.0       450.0
# 6       NaN  121718590   MLA109096                NaN   3000.0      3000.0
# 7       NaN  141127478   MLA431802                NaN    670.0       670.0
# 8       NaN  141127478   MLA429749                NaN    575.0       575.0
# 9       NaN  716394007   MLA373840                NaN      NaN         NaN
#
#    original_price  ...                                domain_id  \
# 0             NaN  ...                        MLA-COFFEE_TABLES
# 1             NaN  ...                       MLA-OTHER_VEHICLES
# 2             NaN  ...            MLA-CANNED_AND_PRESERVED_FOOD
# 3             NaN  ...                           MLA-CELLPHONES
# 4             NaN  ...                           MLA-PROJECTORS
# 5             NaN  ...                              MLA-CANDLES
# 6             NaN  ...                    MLA-JACKETS_AND_COATS
# 7             NaN  ...  MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS
# 8             NaN  ...               MLA-MOBILE_DEVICE_CHARGERS
# 9             NaN  ...                                      NaN
#
#    parent_item_id  differential_pricing  \
# 0            None                   NaN
# 1            None                   NaN
# 2            None                   NaN
# 3            None                   NaN
# 4            None                   NaN
# 5            None                   NaN
# 6            None                   NaN
# 7    MLA906373314                   NaN
# 8    MLA906374038                   NaN
# 9             NaN                   NaN
#
#                                    deal_ids automatic_relist  \
# 0  [MLA27076, MLA27078, MLA24099, MLA27075]            False
# 1                                        []            False
# 2                                        []            False
# 3                                        []            False
# 4                                        []            False
# 5                                        []            False
# 6                                        []            False
# 7                                        []            False
# 8                                        []            False
# 9                                       NaN              NaN
#
#                date_created              last_updated health catalog_listing  \
# 0  2021-04-02T21:30:39.000Z  2023-01-27T23:15:18.000Z   0.85           False
# 1  2021-04-02T21:30:50.000Z  2022-01-22T04:36:39.559Z   0.16           False
# 2  2021-04-02T21:30:50.000Z  2022-11-19T22:37:43.263Z   0.71           False
# 3  2021-04-02T21:30:51.000Z  2022-01-22T04:36:48.461Z   0.62           False
# 4  2021-04-02T21:30:52.000Z  2022-01-22T04:08:13.566Z   0.62           False
# 5  2021-04-02T21:31:00.000Z  2022-01-22T04:12:45.621Z   0.50           False
# 6  2021-04-02T21:31:02.000Z  2022-03-24T21:43:52.750Z   0.75           False
# 7  2021-04-02T21:31:04.000Z  2022-01-22T04:08:15.950Z   0.57           False
# 8  2021-04-02T21:31:11.000Z  2023-01-03T13:50:31.238Z   0.62           False
# 9  2021-04-02T21:31:18.000Z  2023-01-03T15:19:01.425Z    NaN             NaN
#
#                 channels
# 0  [marketplace, mshops]
# 1          [marketplace]
# 2  [marketplace, mshops]
# 3          [marketplace]
# 4          [marketplace]
# 5          [marketplace]
# 6          [marketplace]
# 7          [marketplace]
# 8          [marketplace]
# 9                    NaN
#
# [10 rows x 54 columns]
