# %% [markdown]
# # Vamos a usar los datos que usamos hace dos clases para hacerlos algunas preguntas...
#
# - ¿Podemos graficar un mapa del arbolado de la ciudad de manera mas linda, incluyendo los contornos de la ciudad?
# - ¿Podemos calcular cual es la comuna con mayor densidad de arboles?
# - ¿Podemos representar esa informacion en un mapa?
# - ¿Podemos aprovechar que sabemos donde esta cada arbol graficar el recorrido de una calle?
# - ¿Podemos validar la ubicación sabiendo a que comuna pertenece el arbol?

# %% [markdown]
# # Antes de ver como se hace, veamos la herramienta... (diapo)

# %%
# En https://data.buenosaires.gob.ar/dataset/comunas esta la info de las comunas

# Vamos a leer el archivo

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely.wkt

# Descargamos y abrimos el archivo
comunas = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/comunas/comunas.csv")

display (comunas.head())
#Trasnformamos la columna WKT
comunas["WKT"] = comunas["WKT"].apply(shapely.wkt.loads) 

display(comunas.head())

# Creamos el GeoComunas
geo_comunas = gpd.GeoDataFrame(comunas, geometry='WKT')
display (geo_comunas.head())
# Out:
#                                                  WKT  ID          OBJETO  \
# 0  MULTIPOLYGON (((-58.3800038855693 -34.57002352...   1  LIMITE COMUNAL
# 1  MULTIPOLYGON (((-58.4306058283309 -34.60704708...   3  LIMITE COMUNAL
# 2  MULTIPOLYGON (((-58.4883373673246 -34.62016035...   6  LIMITE COMUNAL
# 3  MULTIPOLYGON (((-58.498384839883 -34.596367656...   7  LIMITE COMUNAL
# 4  MULTIPOLYGON (((-58.5033113250844 -34.59385615...   8  LIMITE COMUNAL
#
#    COMUNAS                                            BARRIOS     PERIMETRO  \
# 0      2.0                                           RECOLETA  21452.838648
# 1      6.0                                          CABALLITO  10990.964471
# 2     10.0  FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...  18332.037457
# 3     11.0  VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....  19987.696155
# 4     12.0  COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...  17232.189372
#
#            AREA
# 0  6.317265e+06
# 1  6.851029e+06
# 2  1.265656e+07
# 3  1.412004e+07
# 4  1.557093e+07
#                                                  WKT  ID          OBJETO  \
# 0  (POLYGON ((-58.3800038855693 -34.5700235247202...   1  LIMITE COMUNAL
# 1  (POLYGON ((-58.4306058283309 -34.6070470885963...   3  LIMITE COMUNAL
# 2  (POLYGON ((-58.4883373673246 -34.6201603572932...   6  LIMITE COMUNAL
# 3  (POLYGON ((-58.498384839883 -34.5963676568872,...   7  LIMITE COMUNAL
# 4  (POLYGON ((-58.5033113250844 -34.5938561595894...   8  LIMITE COMUNAL
#
#    COMUNAS                                            BARRIOS     PERIMETRO  \
# 0      2.0                                           RECOLETA  21452.838648
# 1      6.0                                          CABALLITO  10990.964471
# 2     10.0  FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...  18332.037457
# 3     11.0  VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....  19987.696155
# 4     12.0  COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...  17232.189372
#
#            AREA
# 0  6.317265e+06
# 1  6.851029e+06
# 2  1.265656e+07
# 3  1.412004e+07
# 4  1.557093e+07
#                                                  WKT  ID          OBJETO  \
# 0  MULTIPOLYGON (((-58.38000 -34.57002, -58.38002...   1  LIMITE COMUNAL
# 1  MULTIPOLYGON (((-58.43061 -34.60705, -58.43056...   3  LIMITE COMUNAL
# 2  MULTIPOLYGON (((-58.48834 -34.62016, -58.48820...   6  LIMITE COMUNAL
# 3  MULTIPOLYGON (((-58.49838 -34.59637, -58.49718...   7  LIMITE COMUNAL
# 4  MULTIPOLYGON (((-58.50331 -34.59386, -58.50347...   8  LIMITE COMUNAL
#
#    COMUNAS                                            BARRIOS     PERIMETRO  \
# 0      2.0                                           RECOLETA  21452.838648
# 1      6.0                                          CABALLITO  10990.964471
# 2     10.0  FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...  18332.037457
# 3     11.0  VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....  19987.696155
# 4     12.0  COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...  17232.189372
#
#            AREA
# 0  6.317265e+06
# 1  6.851029e+06
# 2  1.265656e+07
# 3  1.412004e+07
# 4  1.557093e+07

# %%
fig, ax = plt.subplots()
geo_comunas.plot(ax=ax, column="AREA")
geo_comunas.apply(lambda x: ax.annotate(text=x['COMUNAS'], xy=x.WKT.centroid.coords[0], ha='center'), axis=1)
# Out:
# 0      Annotation(-58.3949, -34.5858, '2.0')
# 1      Annotation(-58.4436, -34.6168, '6.0')
# 2     Annotation(-58.5029, -34.6278, '10.0')
# 3     Annotation(-58.4969, -34.6061, '11.0')
# 4     Annotation(-58.4904, -34.5663, '12.0')
# 5     Annotation(-58.4223, -34.5739, '14.0')
# 6     Annotation(-58.4628, -34.5919, '15.0')
# 7     Annotation(-58.4541, -34.5545, '13.0')
# 8      Annotation(-58.3888, -34.6423, '4.0')
# 9      Annotation(-58.4206, -34.6174, '5.0')
# 10     Annotation(-58.4519, -34.6365, '7.0')
# 11     Annotation(-58.4027, -34.6138, '3.0')
# 12     Annotation(-58.4991, -34.6517, '9.0')
# 13     Annotation(-58.4622, -34.6745, '8.0')
# 14     Annotation(-58.3717, -34.6063, '1.0')
# dtype: object

# %%
# Vamos a leer el dataset de arbolado

arboles = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
arboles.head()
# Out:
# C:\Users\Ionatan\AppData\Local\Temp\ipykernel_11800\193727808.py:3: DtypeWarning: Columns (2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   arboles = pd.read_csv("https://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
# 4             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# 1    Exacta      Peltophorum dubium         4.5         Ocupada
# 2    Exacta  Fraxinus pennsylvanica           4         Ocupada
# 3        LD  Fraxinus pennsylvanica         NaN         Ocupada
# 4        LA   Jacaranda mimosifolia         NaN         Ocupada
#
#   ubicacion_plantera nivel_plantera  diametro_altura_pecho  altura_arbol
# 0            Regular        A nivel                   88.0          34.0
# 1            Regular        Elevada                    6.0           5.0
# 2            Regular        A nivel                    7.0           6.0
# 3            Regular        A nivel                    9.0          29.0
# 4            Regular        A nivel                   13.0           8.0

# %%
# generamos el geopandas asociado

geo_arboles = gpd.GeoDataFrame(arboles,geometry=gpd.points_from_xy(arboles.long, arboles.lat))
geo_arboles.head()
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
# 4             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# 1    Exacta      Peltophorum dubium         4.5         Ocupada
# 2    Exacta  Fraxinus pennsylvanica           4         Ocupada
# 3        LD  Fraxinus pennsylvanica         NaN         Ocupada
# 4        LA   Jacaranda mimosifolia         NaN         Ocupada
#
#   ubicacion_plantera nivel_plantera  diametro_altura_pecho  altura_arbol  \
# 0            Regular        A nivel                   88.0          34.0
# 1            Regular        Elevada                    6.0           5.0
# 2            Regular        A nivel                    7.0           6.0
# 3            Regular        A nivel                    9.0          29.0
# 4            Regular        A nivel                   13.0           8.0
#
#                       geometry
# 0  POINT (-58.37856 -34.59490)
# 1  POINT (-58.38153 -34.59232)
# 2  POINT (-58.37910 -34.59194)
# 3  POINT (-58.38071 -34.59155)
# 4  POINT (-58.38071 -34.59155)

# %%
# Probamos graficar los puntos en cada comuna

fig, ax = plt.subplots()

geo_arboles.sample(10000).plot(ax=ax, column = "comuna")
geo_comunas.plot(ax=ax, facecolor="none", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
# Queremos ahora marcar una calle, por ejemplo Av Santa Fe, para eso vamos a buscar los extremos filtrando los datos de los arboles que esten en esa calle y buscando las alturas maximas y minimas

geo_arboles_stafe = geo_arboles[geo_arboles["calle_nombre"] == "Santa Fe Av."]

fig, ax = plt.subplots(dpi=80)

geo_arboles_stafe.plot(ax=ax)
geo_comunas.plot(ax=ax, facecolor="none", edgecolor='black')

plt.savefig('santafe.png', dpi=80)

# %%
list(geo_arboles["calle_nombre"].unique())
# Out:
# ['Esmeralda',
#  'Pellegrini Carlos',
#  'Arroyo',
#  'Reconquista',
#  'Juncal',
#  'Cerrito',
#  'Suipacha',
#  'Rodriguez Peña',
#  'Bouchard',
#  'Callao Av.',
#  'Córdoba Av.',
#  'Além Leandro N. Av.',
#  'Tucumán',
#  'Lavalle',
#  'Montevideo',
#  'San Martín',
#  'Sarmiento',
#  'De Mayo Av.',
#  'Castillo Ramón S. Pte. Av',
#  'Garay Juan de, Av',
#  'Perú',
#  'Uruguay',
#  'Libertad',
#  'Lima',
#  'Guido',
#  'Parera',
#  'Quintana Manuel Presidente Av.',
#  'Güemes Macacha ',
#  'Trinidad Guevara',
#  'Dealessi Pierina',
#  'Cevallos Virrey',
#  'Irigoyen Bernardo de',
#  'Estados Unidos',
#  'Calvo Carlos',
#  'Chacabuco',
#  'Solís',
#  'Humberto Primo',
#  'Azopardo',
#  'Belgrano Av.',
#  'Talcahuano',
#  'Paseo Colón Av.',
#  'Maipú',
#  'Cabral Sargento',
#  'Del Libertador, Av',
#  'Saenz Peña Roque,Pres. Diagonal Norte Av. ',
#  'Santa Fe Av.',
#  'Arenales',
#  'Cochabamba',
#  'San Juan Av.',
#  'Corrientes Av.',
#  'Piedras',
#  'Moreau  de Justo Alicia Av.',
#  'Madero Eduardo Av.',
#  'Dealessi Pierina ',
#  'Moreno',
#  'De la Barra Emma',
#  'Sánchez de Thompson Mariquita',
#  'Cossettini Olga',
#  'Pacini de Alvear Regina',
#  'De Los Inmigrantes Av.',
#  'Zanni Pedro Comodoro',
#  'Ocampo Victoria',
#  'Independencia Av',
#  'Basavilbaso',
#  'Florida',
#  'Chile',
#  'Roca Julio A. Pte. Av.',
#  'Salta',
#  'Alsina Adolfo',
#  'Yrigoyen Hipólito',
#  'Entre Ríos Av.',
#  'Maipú Av.',
#  'Lynch Marta',
#  'Maizani Azucena',
#  'Perón Juan Domingo Tte. Gral.',
#  'Santiago del Estero',
#  'Carabelas',
#  '25 de Mayo',
#  'Tacuarí',
#  'San José de Calasanz',
#  'Py Comodoro Av.',
#  'cerrito',
#  'Balcarce',
#  'Rivadavia, Av',
#  'Caseros Av.',
#  'Fels Pablo T. Cabo',
#  'Villaflor Azucena',
#  '15 de Noviembre de 1889',
#  'Paine Aime',
#  'Eyle Petrona',
#  'Venezuela',
#  'México',
#  'Ezcurra Encarnación',
#  'Defensa',
#  'Brasil Av.',
#  'Rondeau',
#  'Huergo Ingeniero Av.',
#  'Gorriti Juana Manuela',
#  'Bullrich Intendente Av.',
#  'Trinidad guevara',
#  'Mitre Bartolomé',
#  'Pavón Av.',
#  'Posadas',
#  'Grierson Cecilia',
#  'Vera Peñaloza  Rosario ',
#  'San José',
#  'Lanteri Julieta',
#  'Alvear Av.',
#  'Bolívar',
#  'Chile Av.',
#  'San Lorenzo',
#  'Sáenz Manuela',
#  'Paraguay',
#  'Antártida Argentina Av.',
#  '5 de julio',
#  'Tres Sargentos',
#  'Tres sargentos',
#  'Salotti Martha',
#  'Viamonte',
#  'Paraná',
#  'Del Carmen',
#  'Rocha',
#  'Hernandarias',
#  'Acosta Mariano',
#  'Yerbal',
#  'Echagüe Pedro',
#  'Constitución',
#  'Filiberto ',
#  'Brandsen',
#  'Perdriel',
#  'Cortejarena José A. ',
#  'Anchoris',
#  'Hornos Gral.',
#  'Piedras ',
#  '3 de Febrero',
#  "O'Gorman Camila",
#  'Junín',
#  'Anchorena Tomás Manuel de , Dr.',
#  'Azcuénaga',
#  'Jaures Jean',
#  'Ortíz Roberto M. Pres.',
#  'Charcas',
#  'Díaz Cnel. Av.',
#  'Las Heras Gral. Av.',
#  'Sánchez de Bustamante',
#  'Mansilla Lucio N. Gral.',
#  'Laprida',
#  'Uriburu José Evaristo Pte',
#  'Billinghurst',
#  'Güemes',
#  'Gutiérrez Juan María',
#  'Larrea',
#  'Pueyrredón Av.',
#  'Agüero',
#  'Beruti',
#  'Soler',
#  'Pacheco de Melo José Andrés',
#  'Peña',
#  'Riobamba',
#  'Gallo',
#  'French',
#  'López Vicente',
#  'Ecuador',
#  'Ayacucho',
#  'Copérnico',
#  'Gutiérrez Juan María ',
#  'Austria',
#  'Pagano José León',
#  'Tagle',
#  'Cabrera José Antonio',
#  'Gelly y Obes Gral. Av.',
#  'Galileo',
#  'Schiaffino Eduardo',
#  'Newton',
#  'Quirno Costa Norberto Dr.',
#  'Agote Luis Dr.',
#  'Barrientos',
#  'barrientos',
#  'peña',
#  'Gorriti',
#  'De la Cárcova',
#  'Bravo Mario',
#  'french',
#  'Pasco',
#  'Sarandí',
#  'Rincón',
#  'Pichincha',
#  'Jenner Eduardo Dr.',
#  'Zelaya',
#  'Combate de los Pozos',
#  'Matheu',
#  'Alberti',
#  'Urquiza Gral.',
#  'Gómez Valentín',
#  'Pasteur',
#  'San Luis',
#  'Barcala',
#  'Boulogne Sur Mer',
#  'La Rioja',
#  'Oruro',
#  'Paso',
#  'Jujuy Av.',
#  'Saavedra',
#  'Catamarca',
#  'Humahuaca',
#  'Guardia Vieja',
#  'barcala',
#  'Sánchez de Loria',
#  'San luis',
#  'Misiones',
#  'Castelli',
#  'Deán Funes',
#  'Agrelo',
#  '24 de Noviembre',
#  'Gardel Carlos',
#  'Díaz Vélez Av.',
#  'pasco',
#  'Esparza',
#  'Luca Esteban de',
#  'Prudán Manuel Silvestre Tte.',
#  'Danel',
#  'MAtheu',
#  'PAsco',
#  'PaSco',
#  'Chiclana Av.',
#  'matheu',
#  'catamarca',
#  'Discépolo Enrique Santos',
#  'Valle',
#  'Neuquén',
#  'Pérez Galdós Benito Av.',
#  'Arzobispo Espinosa',
#  'Caboto',
#  'Pi y Margall',
#  'Brin Ministro',
#  'Caffarena Agustín R.',
#  'Pilcomayo',
#  'Gualeguay',
#  'Brasil',
#  '20 de Septiembre',
#  "D'Esposito Arnaldo",
#  'Necochea',
#  'Valle Arístobulo del',
#  'Brown Almirante Av.',
#  'Don Pedro de Mendoza Av.',
#  'Blanes Juan Manuel',
#  'Villafañe Wenceslao',
#  'Regimiento de Patricios Av.',
#  'Magallanes',
#  'Suárez',
#  'Olavarría',
#  'Irala',
#  'Rodríguez Martín',
#  'Aráoz De Lamadrid Gregorio Gral.',
#  'Liberti Tomás',
#  'Póliza Práctico',
#  'Pinzón',
#  'Necochea ',
#  'Palos',
#  'Valle Iberlucea del Dr.',
#  'Melo Carlos F.',
#  'Quinquela Martín Benito',
#  'Palacios Alfredo L.',
#  'Salvadores Cnel.',
#  'Garibaldi',
#  'Zolezzi Antonio L.',
#  'Filiberto Juan de Dios',
#  'Pi y margall',
#  'Carbonari Francisco Comandante',
#  'Padre Federico Grote',
#  'Abdala Germán',
#  'García Martín Av.',
#  'Directorio Av.',
#  'Zuviría',
#  'Álvar Nuñez',
#  'Helguera',
#  'Espora Tomás Cnel. de Marina',
#  'Vespucio',
#  'Echeandía',
#  'Falcón Ramón L. Cnel.',
#  'Tapalqué',
#  'Doblas',
#  'Beauchef',
#  'Arriola',
#  'Lavardén',
#  'Finochietto Enrique Dr.',
#  'Gómez Juan Carlos',
#  'Los Patos',
#  'Monteagudo',
#  'Uspallata',
#  'Inclán',
#  'Chutro Pedro Prof. Dr.',
#  'Almafuerte Av.',
#  'Montes de Oca Manuel Av.',
#  'Azara',
#  'Castillo Cátulo',
#  'Suárez Av.',
#  'Isabel La Católica',
#  'El Refrán',
#  'Elía',
#  'Iguazú',
#  'Atuel',
#  'Monasterio',
#  'Los Patos ',
#  'Casacuberta',
#  'Apule',
#  'California',
#  'García Manuel',
#  'Santa Cruz',
#  'Salcedo',
#  'Iriarte Gral.',
#  'Díaz de Guzmán Ruy',
#  'Luna',
#  'Patagones',
#  'Alcorta  Amancio  Av',
#  'Luna ',
#  'Colonia Av.',
#  'Patagones ',
#  'Cooperación',
#  'Garro',
#  'Cerri Daniel Gral.',
#  'Pepirí',
#  'Mutualismo',
#  'Ameghino, Florentino',
#  'Vélez Sarsfield Av.',
#  'Fernández Moreno Baldomero',
#  'Primera Junta',
#  'Azara ',
#  'Salmún Feijóo José Aarón',
#  'Corrales Viejos',
#  'Defensa ',
#  'Vieytes',
#  'Herrera',
#  'Grito de Asencio',
#  'Lanín',
#  'Copahue',
#  'Río Cuarto',
#  'Iriarte Gral. Av.',
#  'Lamadrid',
#  'Zavaleta',
#  'Icalma',
#  'Cortejarena José A.',
#  'Los Telares',
#  'Arcamendia',
#  'Famatina',
#  'Paz José C.',
#  'Masantonio Herminio',
#  'Taborda Diógenes',
#  'Gena',
#  'Guayquiraró',
#  'Miriñay',
#  'Ferreyra Andrés',
#  'Cachi',
#  'Guanahani',
#  'Ituzaingó',
#  'Pedriel',
#  'Luzuriaga',
#  'Alagon',
#  'Pomar Gregorio Tte. Cnel. ',
#  'Agaces',
#  'Mocoreta ',
#  'Mocoreta',
#  'Guaraní',
#  'Achala',
#  'Taborda',
#  'Llorente',
#  'Pagola Cnel.',
#  'Sáenz Av.',
#  'Quilmes',
#  'Trole',
#  'Berón de Astrada',
#  'Goncalves Dias',
#  'Alvarado',
#  'San Antonio',
#  'Paz Gral. Av.',
#  'Raulet',
#  'Del Tigre',
#  'Gómez Indalecio',
#  'Chilavert Martiniano Cnel.',
#  'Mom',
#  'Barros Pazos',
#  'Cacique',
#  'Lanza',
#  'Seguín Marcos',
#  'Ancaste',
#  'Daract Av.',
#  'Somellera',
#  'Tilcara',
#  'Salvigny',
#  'Arquímedes',
#  'Pirovano',
#  'Natal',
#  'Riestra Av.',
#  'Erezcano',
#  'Corrales',
#  'Crespo',
#  'Pola',
#  'Miralla',
#  'Casco Horacio Dr.',
#  'Cobo Av.',
#  'Sánchez de Loria Av.',
#  'Ochoa Enrique',
#  'Luján',
#  'Cotagaita',
#  'San Ricardo',
#  'Los patos',
#  'Vedia Agustín de',
#  'Rivera Fructuoso Gral.',
#  'Saladillo',
#  'Madariaga',
#  'Villarino',
#  'Cruz Osvaldo Av.',
#  'Barco Centenera del Av.',
#  'Arbeletche Anibal P',
#  'Moreno Perito Av.',
#  'Fournier',
#  'Tabaré',
#  'Montesquieu',
#  'Tilcara Av.',
#  'Manzi Homero',
#  'Guzmán Av.',
#  'Paracas',
#  'Olmos Ambrosio ',
#  'Drumond',
#  'La Plata Av.',
#  'Espinosa',
#  'Mirave',
#  'Samperio',
#  'Toll',
#  'los patos',
#  'Perdriel ',
#  'Luzuriaga ',
#  'Mujica José Pío',
#  'Lagos',
#  'Puna',
#  'Rawson de Dellepiane Elvira Av',
#  'España Av.',
#  'Parker',
#  'Cruz Osvaldo',
#  'VIEYTES',
#  'Rico Cnel.',
#  'Santo Domingo',
#  'Jorge',
#  'Lavadero',
#  'Australia Av.',
#  'Pinedo Av.',
#  'Rochdale',
#  'Owen',
#  'Meana Benito Cnel.',
#  'Santa Elena',
#  'Santa María del Buen Aire',
#  'Salom',
#  'Santa Magdalena',
#  'Río Limay',
#  'Renacimiento',
#  'Spika Enrique Gral.',
#  'Azcúenaga Domingo de',
#  'Santo Domingo ',
#  'Jorge ',
#  'Algarrobo',
#  'Algarrobo ',
#  'Santa Elena ',
#  'Melgar',
#  'Mandisobi',
#  'Cruz del Sud',
#  'Darquier Juan',
#  'Zepita',
#  'Lugo',
#  'La Trilla',
#  'Del Bañado',
#  'Gual',
#  'Echagüe Carlos Ing.',
#  'Daract',
#  'Saldías Adolfo',
#  'Janer Ana María',
#  'El Ceibo',
#  'Pazos',
#  'La Constancia',
#  'Juana de Arco',
#  'Dekay',
#  'Ramírez Carlos M.',
#  'Corrales ',
#  'Las Palmas',
#  'Las palmas',
#  'Tierra del Fuego ',
#  'Tierra del Fuego',
#  'Esquiú',
#  'Cóndor',
#  'Santa Catalina',
#  'Luppi Abraham J.',
#  'Maderna Francisco',
#  'Charrúa',
#  'Bonorino Esteban Cnel. Av.',
#  'Matanza',
#  'Erezcano ',
#  'Itaquí',
#  'Einstein Alberto',
#  'Ventana',
#  'Verdaguer Jacinto',
#  'Bonavena Oscar Natalio',
#  'Traful',
#  'Magnaud Juez',
#  'Lynch',
#  'Beazley',
#  'Vega Ventura de la ',
#  'Gutiérrez Alfredo G.',
#  'Romero',
#  'Falucho',
#  'Colmo Alfredo',
#  'Romero ',
#  'Ferré',
#  'Erezcano Av.',
#  '27 de Febrero Av.',
#  'Echauri',
#  'Thome Juan M.',
#  'Mar Dulce',
#  'Mar dulce',
#  'Cabred Domingo Dr.',
#  'Turquía',
#  'Guaymallén',
#  'Lancheros del Plata',
#  'Beruti Arturo',
#  'Pittaluga Eduardo',
#  'lavalle',
#  'Acuña  de Figueroa Francisco',
#  'Rocamora',
#  'Rawson',
#  'Gascón',
#  'Medrano Av.',
#  'Obrero Roberto Núñez',
#  'Bulnes',
#  'Yatay',
#  'Pringles',
#  'Salguero Jerónimo ',
#  'Estado de Israel Av.',
#  'Lambaré',
#  'Potosí',
#  'Estado de Palestina',
#  'Troilo Anibal',
#  'Río de Janeiro',
#  'Gallardo Angel Av',
#  'Yapeyú',
#  'Liniers Virrey',
#  'Maza',
#  'Castro Barros Av.',
#  'Bocayuva Quintino',
#  'Tarija',
#  'Devoto Fortunato',
#  'Castro',
#  'Mármol José',
#  'Treinta y tres Orientales',
#  'Palestina',
#  'Panamá',
#  'Muñiz',
#  'Spegazzini Carlos',
#  'Rauch',
#  'Colombres',
#  'Boedo Av.',
#  'Don Bosco',
#  'Bogado',
#  'Belgrano',
#  'Quito',
#  'Don bosco',
#  'Lezica',
#  'Estado de palestina',
#  'rocamora',
#  'Metán',
#  'Inca',
#  'Cabot',
#  'Sánchez De Loria Av.',
#  'maza',
#  'Bathurst',
#  'Gibson',
#  'Timbues',
#  'Las Casas',
#  'Álzaga',
#  'Pereyra',
#  'Jantin Juan Bautista',
#  'Las casas',
#  'Gallegos',
#  'Calvo Carlos Av.',
#  'las casas',
#  'quito',
#  'Querandies',
#  'Bidegain Pedro',
#  'agrelo',
#  'Libres',
#  'San Ignacio',
#  'Venialvo',
#  'Peluffo Angel',
#  'Medrano',
#  'castro',
#  'King',
#  'cochabamba',
#  'López Anaut Pedro Dr.',
#  'pringles',
#  'Rosario',
#  'Montiel',
#  'San Pedrito Av.',
#  'Rivera Indarte Av.',
#  'Franklin',
#  'Ampere',
#  'Rojas',
#  'Gainza Martín de Gral.',
#  'Pueyrredón Honorio Dr. Av.',
#  'Álvarez Donato Tte. Gral. Av.',
#  'Belaústegui Luis Dr.',
#  'Sor Juana Inés de La Cruz',
#  'Planes',
#  'Pujol',
#  'Arengreen',
#  'Galicia',
#  'San Martín Av.',
#  'Viale Luis',
#  'Cucha  Cucha',
#  'Figueroa Apolinario Cnel.',
#  'Repetto Nicolás Dr.',
#  'Tres Arroyos',
#  'Virasoro Valentín ',
#  'Olaya',
#  'Demaria Isidoro',
#  'Fragata Presidente Sarmiento',
#  'Maciel Francisco A.',
#  'Oroño Nicasio',
#  'Paysandú',
#  'Amberes',
#  'Ambrosetti Juan B.',
#  'Hidalgo',
#  'Gaona Av.',
#  'Machado Antonio',
#  'Ramos Mejía',
#  'Portugal',
#  'Bogotá',
#  'García Lorca Federico',
#  'Avellaneda Av.',
#  'Acoyte Av.',
#  'Aráoz Alfaro Gregorio Dr.',
#  'Aranguren Juan F. Dr.',
#  'Otamendi',
#  'Jauretche Arturo',
#  'Biedma Juan José',
#  'Vallese Felipe',
#  'Campichuelo',
#  'Morelos',
#  'Lobos Eleodoro Dr.',
#  'Osaka',
#  'Patricias Argentinas Av. ',
#  'Marechal Leopoldo',
#  'Estivao',
#  'Cangallo',
#  'Rodríguez Manuel A. Gral.',
#  'San Sebastián',
#  'Méndez de Andes',
#  'Ibarbourou Juana de',
#  'Vila Nicolás',
#  'Centenario',
#  'Colpayo',
#  'Parral',
#  'Bacacay',
#  'Dinamarca',
#  'Flores Venancio Gral. ',
#  'Giordano Bruno',
#  'Viel',
#  'Guayaquil',
#  'Acevedo Eduardo',
#  'Vintter Lorenzo Gral.',
#  'San Ireneo',
#  'Bruno Giordano',
#  'Alvarez Donato Tte. Gral.',
#  'Goyena Pedro Av.',
#  'Malvinas Argentinas',
#  'Bonifacio José',
#  'Hortiguera',
#  'Martínez Víctor',
#  'Matorras',
#  'Senillosa',
#  'Lora Félix',
#  'hidalgo',
#  'La Mar',
#  'Chaco',
#  'El Maestro',
#  'Alberdi Juan Bautista Av.',
#  'Bertres',
#  'Escribano',
#  'Hualfin',
#  'Thompson',
#  'Formosa',
#  'Moreno José María Av.',
#  'Riglos',
#  'Ortega',
#  'Curapaligüe',
#  'Demaria',
#  'San ireneo',
#  'Republica de indonesia',
#  'Mitre Emilio',
#  'Esnaola',
#  'Terry José A.',
#  'riglos',
#  'Craig',
#  'Cachimayo',
#  'Achaval',
#  'La Nave',
#  'Miró',
#  'Puán',
#  'Epuyen',
#  'Campos Gaspar',
#  'Videla Nicolás ',
#  'Numancia',
#  'valle',
#  'viel',
#  'rojas',
#  'colpayo',
#  'La nave',
#  'Lamarca Emilio',
#  'Thorne',
#  'Malvinas argentinas',
#  'Chirimay',
#  'Republica de Indonesia',
#  'Maiten',
#  'Gimenez Angel M.',
#  'Alvarez Thomas Av.',
#  'Finlandia',
#  'La Facultad',
#  'Estado Plurinacional de Bolivia',
#  'Artigas José Gervasio Gral.',
#  'Igualdad',
#  'Carriego Evaristo ',
#  'Laferrere Gregorio de',
#  'Pedernera',
#  'Guaminí',
#  'Pergamino',
#  'Saraza',
#  'Muzilli Carolina',
#  'Tandíl',
#  'Martínez Castro',
#  'Balbastro',
#  'Díaz Avelino ',
#  'Pumacahua',
#  'Carabobo Av.',
#  'Dávila',
#  'Caracas',
#  'Fray Cayetano Rodríguez',
#  'Trelles Manuel Ricardo',
#  'Gavilán',
#  'Argerich',
#  'Páez',
#  'Granaderos',
#  'Tejedor',
#  'Estrada',
#  'De Las Ciencias',
#  'Albarracín',
#  'Perón Eva Av.',
#  'Condarco',
#  'Terrada',
#  'Nazca Av',
#  'Santander',
#  'Bufano Alfredo R.',
#  'Morón',
#  'La Porteña',
#  'Díaz Avelino',
#  'Castañares Av.',
#  'Zelarrayán',
#  'Bilbao Francisco Av.',
#  'Robla Juan F. de la',
#  'Lafuente Av.',
#  'Terrero',
#  'Culpina',
#  'Asamblea Av.',
#  'Cuenca',
#  'Timbo',
#  'Lautaro',
#  'Monte Dinero',
#  'Beiró Francisco  Av.',
#  'Irigoyen',
#  'Hugo Víctor',
#  'Del Buen Orden',
#  'Cálcena',
#  'Bahía Blanca',
#  'González Joaquín V. ',
#  'Escalada Av.',
#  'Escalada de San Martín Remedios ',
#  'Membrillar',
#  'Riccio Gustavo',
#  'Salas',
#  'Camacuá',
#  'Vernet Av.',
#  'Varela',
#  'Rodríguez Cayetano',
#  'Recuero Casimiro Tte. Cnel.',
#  'Zañartú',
#  'Bialet Masse',
#  'Culpina ',
#  'Picheuta',
#  'Caricancha',
#  'Portela',
#  'Martí José',
#  'Boyacá',
#  'Cranwell',
#  'Lamas Andrés',
#  'Cipolletti',
#  'Fray Luis Beltrán',
#  'Padre Lorenzo B. Massa',
#  'De la Industria',
#  'De las Artes',
#  'De las Artes ',
#  'Caballito',
#  'Asia',
#  'Faraday',
#  'Curapaligüe Av.',
#  'Castro Juan de',
#  'República',
#  'El Artesano',
#  'Quirno',
#  'hortiguera',
#  'Fraternidad',
#  'De las Garantías',
#  'Del Comercio',
#  'De La Artes',
#  'De Las Artes',
#  'Yerbal ',
#  'Del Progreso',
#  'Caperucita',
#  'El Zonda',
#  'Chivilcoy Av.',
#  'Castañón',
#  'Garzón Eugenio Gral. Av.',
#  'Naón Juan José',
#  'Alvarez Crisóstomo ',
#  'Zuviría ',
#  'Beltrán',
#  'Bell Ville',
#  'Pillado',
#  'Viel ',
#  'Eguía Manuel',
#  'Perrault',
#  'Remedios',
#  'Don Segundo Sombra',
#  'Robertson',
#  'Valencia',
#  'Miraflores',
#  'Manco capac',
#  'Lanús',
#  'Ortíz Carlos',
#  'Espartaco',
#  'membrillar',
#  'membrillar ',
#  'Torres y Tenorio',
#  'Brown Frank',
#  'Plácido Martinez',
#  'Centenera',
#  'lautaro ',
#  'lautaro',
#  'Manco Capac',
#  'Portela ',
#  'Arrotea',
#  'Renan',
#  'Varela Av.',
#  'Zapala',
#  'Fabre',
#  'Gómez Somavilla Joaquín',
#  'Del progreso',
#  'La Capital',
#  'Ramón y Cajal',
#  'Franklin ',
#  'Guardia Nacional',
#  'Corvalán',
#  'De La Industria',
#  'Nepper',
#  'Velázquez',
#  'Balbín Ricardo, Dr. Av',
#  'Cambieses Eustaquio',
#  'Italia',
#  'Espejo Gerónimo',
#  'Leguizamón Martiniano ',
#  'Levalle Nicolás',
#  'Calasanz',
#  'Pumacahua ',
#  'Thorne ',
#  'Cosquín',
#  'Castillo Juan del ',
#  'Aroma',
#  'González Roque',
#  'Santander ',
#  'Ucacha',
#  'La Galera',
#  'Diez de Medina Clemente',
#  'Navarro Viola Miguel',
#  'Asamblea Av,',
#  'Rodríguez Alonso',
#  'Miramar',
#  'Patrón',
#  'Hubac',
#  'Olivera Av.',
#  'Moreno Enrique B.',
#  'Gordillo Timoteo',
#  'Cañada de Gómez',
#  'Piedrabuena Av.',
#  'Montreal ',
#  'Montreal',
#  'Larraya',
#  'De la Torre, Lisandro Av.',
#  'Fonrouge',
#  'Albariño',
#  'Larrazábal Av.',
#  'De La Rosa José Dr.',
#  'Roca Cnel. Av.',
#  'Basualdo',
#  'Unanué',
#  'Hicken Cristobal M.',
#  'Güiraldes Ricardo',
#  'Soria Ezequiel ',
#  'Araujo ',
#  'Cura Brochero',
#  'Suárez José León ',
#  'Cura brochero',
#  'Murguiondo',
#  'Larraya ',
#  'Matteoti Giácomo',
#  'Villa de Masnou',
#  'De Simone Vicente',
#  'Managua',
#  'larraya',
#  'Posta de Hornillos',
#  'Oliden',
#  'Argentina Av.',
#  'Rucci José Ignacio',
#  'Sayos',
#  'Cafayate',
#  'Hudson Guillermo',
#  'Gallo Delfín',
#  'Aquino',
#  "O'Gorman",
#  'Berg Carlos',
#  'Pizarro Francisco',
#  'Montiel ',
#  'Escalada Celedonio Cmte.',
#  'Ozanam Federico Beato',
#  'Goleta Juliet',
#  'Correa Morales Lucio',
#  ' Corrales',
#  'Rodrigo de Triana',
#  ' Oliden',
#  'Pola ',
#  'Maldonado',
#  'Racedo Eduardo Tte.',
#  'Soldado de la Frontera Av.',
#  'Somellera ',
#  'Corbeta Belfast',
#  'Goleta Fortuna',
#  'Varela ',
#  'Sumaca Itatí',
#  'Goleta Maldonado',
#  'Bergantin Nancy',
#  'Sumaca Santísima Trinidad',
#  'Bergantin Vigilante',
#  'Grandoli Martín',
#  'Del Colegio',
#  'Alfarero',
#  'La Mesopotamia',
#  'Aquino ',
#  'Rio Negro',
#  'Mozart',
#  'Uriburu Napoleón Gral.',
#  'Santiago Costamagna',
#  'García Pedro A. Cnel.',
#  'Díaz Ana',
#  'Villegas Conrado Gral.',
#  'Descalzi Nicolás',
#  'Guerrico Martín Contralmirante',
#  'Ramírez Ceferino Comodoro',
#  'Bergantín Gral. Belgrano',
#  'Fragata 25 de mayo',
#  'Cañonera América',
#  'Bergantín Gral. Balcarce',
#  'Falucho San Luis',
#  'Bergantin Echagüe',
#  'Falucho San Luis ',
#  'Goleta Sarandí',
#  'Fragata 25 de Mayo',
#  'Balandra Carmen',
#  'Corbeta Agreable',
#  'Sumaca Itati',
#  'Goleta Julia',
#  'Cuter Luisito',
#  'Bergantin Goleta Espora',
#  'Barca Cabo de Hornos',
#  'Goleta Manuelita',
#  'Pailebot Davison',
#  'Goleta Santa Cruz',
#  '2 de Abril de 1982',
#  'Ibañez',
#  'Matorras de San Martín Gregoria',
#  'Estévez José Ing.  ',
#  'Méndez',
#  'Barcelona',
#  'Caaguazú',
#  'Tonelero',
#  'Bosch Ventura ',
#  'Luchter Sur ',
#  'Peribebuy',
#  ...]

# %%
#Buscamos ahora los extremos
from shapely.geometry import LineString
from shapely.geometry import Point

# geo_arboles_corrientes["calle_altura"].max() #Ver que da error porque hay nans

geo_arboles_stafe = geo_arboles[geo_arboles["calle_nombre"] == "Santa Fe Av."]
#geo_arboles_stafe = geo_arboles_stafe.dropna()
geo_arboles_stafe["calle_chapa"] = geo_arboles_stafe["calle_chapa"].astype('float')

geo_arboles_stafe = geo_arboles_stafe.sort_values("calle_chapa")
#partida = geo_arboles_corrientes[geo_arboles_corrientes["calle_altura"]==geo_arboles_corrientes["calle_altura"].min()].geometry
#llegada = geo_arboles_corrientes[geo_arboles_corrientes["calle_altura"]==geo_arboles_corrientes["calle_altura"].max()].geometry

geo_arboles_stafe = geo_arboles_stafe[:-geo_arboles_stafe["calle_chapa"].isna().sum()] # Nos sacamos de encima los datos que no figuran 

# Es molesto que hay que pasar a points
type(geo_arboles_stafe["geometry"].iloc[0])
linea = LineString([geo_arboles_stafe["geometry"].iloc[0],geo_arboles_stafe["geometry"].iloc[-1]])

geo_linea = gpd.GeoSeries([linea])

fig, ax = plt.subplots(dpi=80)

geo_linea.plot(ax=ax)
geo_comunas.plot(ax=ax, facecolor="none", edgecolor='black')
# Out:
# C:\Users\Ionatan\AppData\Local\Temp\ipykernel_11800\2844217597.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geo_arboles_stafe["calle_chapa"] = geo_arboles_stafe["calle_chapa"].astype('float')
# <AxesSubplot:>

# %%
# Ahora le vamos a agregar resolucion

n = 5
puntos = geo_arboles_stafe["geometry"][0::n].to_list()

linea = LineString(puntos)
geo_linea = gpd.GeoSeries(linea)

fig, ax = plt.subplots(dpi=800)

geo_linea.plot(ax=ax)
geo_comunas.plot(ax=ax, facecolor="none", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
# Ahora queremos validar si los arboles estan marcados en la comuna correcta. Como son muchos datos vamos a trabajar solo con una comuna.

comuna = 1

geo_comunas_seleccionada = geo_comunas[geo_comunas["COMUNAS"]==comuna]
geo_arbolado_comuna_seleccionada = geo_arboles[geo_arboles["comuna"] == comuna]


fig, ax = plt.subplots(dpi=80)

geo_arbolado_comuna_seleccionada.plot(ax=ax)
geo_comunas_seleccionada.plot(ax=ax, facecolor="none", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
geometria = geo_comunas_seleccionada["WKT"]

for i in geo_arbolado_comuna_seleccionada.index:
    geo_arbolado_comuna_seleccionada.loc[i,"pertenece"] = geometria.contains(geo_arbolado_comuna_seleccionada.loc[i, 'geometry']).iloc[0]
# Out:
# C:\Users\Ionatan\AppData\Local\Temp\ipykernel_11800\1232225897.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geo_arbolado_comuna_seleccionada.loc[i,"pertenece"] = geometria.contains(geo_arbolado_comuna_seleccionada.loc[i, 'geometry']).iloc[0]

# %%
fig, ax = plt.subplots(dpi=800)

geo_arbolado_comuna_seleccionada[geo_arbolado_comuna_seleccionada["pertenece"]==False].plot(ax=ax)
geo_comunas_seleccionada.plot(ax=ax, facecolor="none", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
#geo_comunas.crs
#geo_comunas.crs = {'init' :'epsg:4326'}
#geo_comunas_m = geo_comunas.copy()
#geo_comunas_m.to_crs('epsg:6933')
#geo_comunas_m = geo_comunas_m.to_crs({'init': 'epsg:6933'})

# %%
# Vamos a resolver la pregunta de la densidad de arboles

for i in geo_comunas.index:
    arboles_en_comuna = len(geo_arboles[geo_arboles["comuna"]==geo_comunas.loc[i,"COMUNAS"]])
    geo_comunas.loc[i,"arboles"] = arboles_en_comuna
    area = geo_comunas.loc[i,"WKT"].area
    geo_comunas.loc[i,"area"] = area

geo_comunas["densidad"] = geo_comunas["arboles"]/(geo_comunas["area"]*1000000) #Nota aca hay un tema con las unidades el *10000 es para que quede numeros a una escala razonable

geo_comunas
# Out:
#                                                   WKT  ID          OBJETO  \
# 0   MULTIPOLYGON (((-58.38000 -34.57002, -58.38002...   1  LIMITE COMUNAL
# 1   MULTIPOLYGON (((-58.43061 -34.60705, -58.43056...   3  LIMITE COMUNAL
# 2   MULTIPOLYGON (((-58.48834 -34.62016, -58.48820...   6  LIMITE COMUNAL
# 3   MULTIPOLYGON (((-58.49838 -34.59637, -58.49718...   7  LIMITE COMUNAL
# 4   MULTIPOLYGON (((-58.50331 -34.59386, -58.50347...   8  LIMITE COMUNAL
# 5   MULTIPOLYGON (((-58.42676 -34.55202, -58.42676...   9  LIMITE COMUNAL
# 6   MULTIPOLYGON (((-58.42602 -34.59661, -58.42484...  11  LIMITE COMUNAL
# 7   MULTIPOLYGON (((-58.44033 -34.54022, -58.44032...  15  LIMITE COMUNAL
# 8   MULTIPOLYGON (((-58.38864 -34.63373, -58.38864...  13  LIMITE COMUNAL
# 9   MULTIPOLYGON (((-58.43333 -34.60267, -58.43314...   2  LIMITE COMUNAL
# 10  MULTIPOLYGON (((-58.46040 -34.65681, -58.46041...   4  LIMITE COMUNAL
# 11  MULTIPOLYGON (((-58.41192 -34.59800, -58.41029...  10  LIMITE COMUNAL
# 12  MULTIPOLYGON (((-58.50252 -34.67451, -58.50253...   5  LIMITE COMUNAL
# 13  MULTIPOLYGON (((-58.46040 -34.65681, -58.46040...  12  LIMITE COMUNAL
# 14  MULTIPOLYGON (((-58.36854 -34.57365, -58.36852...  14  LIMITE COMUNAL
#
#     COMUNAS                                            BARRIOS     PERIMETRO  \
# 0       2.0                                           RECOLETA  21452.838648
# 1       6.0                                          CABALLITO  10990.964471
# 2      10.0  FLORESTA - MONTE CASTRO - VELEZ SARSFIELD - VE...  18332.037457
# 3      11.0  VILLA DEL PARQUE - VILLA  DEVOTO - VILLA GRAL....  19987.696155
# 4      12.0  COGHLAN - SAAVEDRA - VILLA PUEYRREDON - VILLA ...  17232.189372
# 5      14.0                                            PALERMO  22126.531858
# 6      15.0  AGRONOMIA - CHACARITA -  PARQUE CHAS -  PATERN...  17832.585580
# 7      13.0                      BELGRANO - COLEGIALES - NUÑEZ  26198.826953
# 8       4.0  BARRACAS - BOCA - NUEVA POMPEYA - PARQUE PATRI...  35423.282799
# 9       5.0                                    ALMAGRO - BOEDO  12323.432479
# 10      7.0                          FLORES - PARQUE CHACABUCO  17972.257870
# 11      3.0                          BALVANERA - SAN CRISTOBAL  10486.260809
# 12      9.0            LINIERS - MATADEROS - PARQUE AVELLANEDA  21411.738344
# 13      8.0     VILLA LUGANO - VILLA RIACHUELO - VILLA SOLDATI  20935.012513
# 14      1.0  CONSTITUCION - MONTSERRAT - PUERTO MADERO - RE...  36102.201573
#
#             AREA  arboles      area    densidad
# 0   6.317265e+06   7115.0  0.000621  114.628661
# 1   6.851029e+06  15591.0  0.000673  231.529145
# 2   1.265656e+07  33421.0  0.001244  268.617950
# 3   1.412004e+07  37340.0  0.001388  269.078817
# 4   1.557093e+07  38818.0  0.001530  253.784592
# 5   1.584587e+07  22417.0  0.001557  144.002349
# 6   1.432290e+07  29587.0  0.001407  210.225655
# 7   1.471321e+07  28287.0  0.001445  195.743256
# 8   2.168464e+07  32346.0  0.002132  151.713965
# 9   6.660603e+06  15224.0  0.000655  232.541316
# 10  1.242290e+07  25608.0  0.001221  209.671217
# 11  6.385991e+06  13320.0  0.000628  212.216470
# 12  1.650531e+07  36405.0  0.001623  224.308592
# 13  2.221690e+07  21978.0  0.002185  100.576506
# 14  1.779457e+07  12723.0  0.001749   72.751864

# %%
fig, ax = plt.subplots()
geo_comunas.plot(ax=ax, column="densidad", legend=True)
geo_comunas.apply(lambda x: ax.annotate(text=round(x['densidad'],2), xy=x.WKT.centroid.coords[0], ha='center'), axis=1)
# Out:
# 0     Annotation(-58.3949, -34.5858, '114.63')
# 1     Annotation(-58.4436, -34.6168, '231.53')
# 2     Annotation(-58.5029, -34.6278, '268.62')
# 3     Annotation(-58.4969, -34.6061, '269.08')
# 4     Annotation(-58.4904, -34.5663, '253.78')
# 5      Annotation(-58.4223, -34.5739, '144.0')
# 6     Annotation(-58.4628, -34.5919, '210.23')
# 7     Annotation(-58.4541, -34.5545, '195.74')
# 8     Annotation(-58.3888, -34.6423, '151.71')
# 9     Annotation(-58.4206, -34.6174, '232.54')
# 10    Annotation(-58.4519, -34.6365, '209.67')
# 11    Annotation(-58.4027, -34.6138, '212.22')
# 12    Annotation(-58.4991, -34.6517, '224.31')
# 13    Annotation(-58.4622, -34.6745, '100.58')
# 14     Annotation(-58.3717, -34.6063, '72.75')
# dtype: object
